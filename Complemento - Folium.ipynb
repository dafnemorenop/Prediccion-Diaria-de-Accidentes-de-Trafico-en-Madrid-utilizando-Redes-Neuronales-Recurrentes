# %%
import ssl
import utm
import pandas as pd
import numpy as np
import geocoder
import folium
import json
import os
import geopandas as gpd
import matplotlib.pyplot as plt
from pyproj import Proj, transform

# %% [markdown]
# **Cargamos primero el picke**

# %%
df = pd.read_pickle("accidentes_pkl.pkl")

# %% [markdown]
# **La idea es "limpiar" la columna localización de caracteres "raros" y separar calles que son cruces**

# %%
df['localizacion']
# Out:
# 0         calle de cartagena num                        ...
# 1         calle de cartagena num                        ...
# 2         calle de cartagena num                        ...
# 3         autovia  m-30 calzada 2 km.                   ...
# 4         autovia  m-30 calzada 2 km.                   ...
#                                 ...
# 478778         call. virgen de lluc / call. buen gobernador
# 478779         call. virgen de lluc / call. buen gobernador
# 478780                                paseo. juan xxiii, 16
# 478781                                paseo. juan xxiii, 16
# 478782                         avda. monforte de lemos, 172
# Name: localizacion, Length: 478783, dtype: object

# %%
# Eliminamos utilizando regex diferentes simbolos y datos de la columna localización 
df['localizacion'] = df['localizacion'].str.replace(r'[,]?\d+$', '', regex=True)
df.loc[:, 'localizacion'] = df.loc[:, 'localizacion'].str.replace('call.', 'calle', regex=False)
df.loc[:, 'localizacion'] = df.loc[:, 'localizacion'].str.replace('num', '', regex=False)
df.loc[:, 'localizacion'] = df.loc[:, 'localizacion'].str.replace(',', '', regex=False)
df.loc[:, 'localizacion'] = df.loc[:, 'localizacion'].str.replace('c/', '', regex=False)
df.loc[:, 'localizacion'] = df.loc[:, 'localizacion'].str.replace('c/ ', '', regex=False)
df.loc[:, 'localizacion'] = df.loc[:, 'localizacion'].str.replace('/', '-', regex=False)
df.loc[:, 'numero'] = df.loc[:, 'numero'].str.replace('0', '', regex=False)
df
# Out:
#         accidente_id      fecha  rango_horario  \
# 0        2010.135000 2010-01-01              0
# 1        2010.135000 2010-01-01              0
# 2        2010.135000 2010-01-01              0
# 3        2010.940000 2010-01-01              1
# 4        2010.940000 2010-01-01              1
# ...              ...        ...            ...
# 478778   2024.004705 2024-01-31              9
# 478779   2024.004705 2024-01-31              9
# 478780   2024.005341 2024-01-27             13
# 478781   2024.005341 2024-01-27             13
# 478782   2024.006301 2024-01-29             21
#
#                                              localizacion numero  \
# 0       calle de cartagena                            ...     14
# 1       calle de cartagena                            ...     14
# 2       calle de cartagena                            ...     14
# 3       autovia  m-30 calzada 2 km.                   ...     12
# 4       autovia  m-30 calzada 2 km.                   ...     12
# ...                                                   ...    ...
# 478778       calle virgen de lluc - calle buen gobernador     12
# 478779       calle virgen de lluc - calle buen gobernador     12
# 478780                                 paseo. juan xxiii      16
# 478781                                 paseo. juan xxiii      16
# 478782                           avda. monforte de lemos     172
#
#                    distrito  coordenada_x  coordenada_y     condicion  \
# 0                 chamartin           NaN           NaN  desfavorable
# 1                 chamartin           NaN           NaN  desfavorable
# 2                 chamartin           NaN           NaN  desfavorable
# 3        puente de vallecas           NaN           NaN     favorable
# 4        puente de vallecas           NaN           NaN     favorable
# ...                     ...           ...           ...           ...
# 478778        ciudad lineal    444464.372   4476185.781     favorable
# 478779        ciudad lineal    444464.372   4476185.781     favorable
# 478780             chamberi    439084.688   4477567.644     favorable
# 478781             chamberi    439084.688   4477567.644     favorable
# 478782  fuencarral-el pardo    439356.877   4480962.780     favorable
#
#                                lesividad persona_implicada  positiva_alcohol  \
# 0                   ingreso inferior 24h         conductor               NaN
# 1                   ingreso inferior 24h         conductor               NaN
# 2       asistencia sanitaria sin ingreso          pasajero               NaN
# 3       asistencia sanitaria sin ingreso          pasajero               NaN
# 4       asistencia sanitaria sin ingreso          pasajero               NaN
# ...                                  ...               ...               ...
# 478778  asistencia sanitaria sin ingreso         conductor               0.0
# 478779          sin asistencia sanitaria         conductor               0.0
# 478780                               NaN         conductor               0.0
# 478781                               NaN         conductor               0.0
# 478782                               NaN         conductor               0.0
#
#         positiva_droga  rango_edad    sexo     tipo_accidente tipo_vehiculo  \
# 0                  NaN         5.0  hombre     colision doble       turismo
# 1                  NaN        12.0  hombre     colision doble       turismo
# 2                  NaN        10.0   mujer     colision doble       turismo
# 3                  NaN         7.0   mujer  colision multiple           NaN
# 4                  NaN         8.0   mujer  colision multiple           NaN
# ...                ...         ...     ...                ...           ...
# 478778             NaN         8.0  hombre     colision doble     bicicleta
# 478779             NaN         9.0   mujer     colision doble       turismo
# 478780             NaN         7.0   mujer     colision doble       turismo
# 478781             NaN        16.0  hombre     colision doble       turismo
# 478782             NaN         9.0  hombre       otras causas       turismo
#
#         victimas
# 0            1.0
# 1            1.0
# 2            1.0
# 3            7.0
# 4            7.0
# ...          ...
# 478778       NaN
# 478779       NaN
# 478780       NaN
# 478781       NaN
# 478782       NaN
#
# [478783 rows x 18 columns]

# %% [markdown]
# **Ahora vamos a crear una nueva columna que se llamará localización completa sumando localizacion y numero**
#
# El objetivo de hacer esto es para ir identificando localizaciones que se repitan con el objetivo de buscar puntos negros

# %%
def combinar_localizacion_numero(row):
    # Combinamos 'localizacion' y 'numero' si 'numero' no es NaN ni está vacío
    if pd.notna(row['numero']) and row['numero'] != '':
        return f"{row['localizacion']}, {row['numero']}"
    # Devolver solo 'localizacion' si 'numero' es NaN o está vacío
    else:
        return row['localizacion']

df['localizacion_completa'] = df.apply(combinar_localizacion_numero, axis=1)

# %% [markdown]
# **Ahora lo que vamos a hacer es separar las direcciones que son cruces para buscar coordenadas**

# %%
df = df.copy()
# Vamos a dividir la columna 'localizacion' en dos nuevas columnas 'direccion_1' y 'direccion_2'
# usando el guión como separador la función expand=True hará que el resultado se divida en columnas separadas
direcciones = df['localizacion'].str.split(' - ', expand=True)

df['direccion_1'] = direcciones[0]
df['direccion_2'] = direcciones[1] if direcciones.shape[1] > 1 else None

# %% [markdown]
# **Aquí lo que hacemos es eliminar los duplicados de accidente_id, ya que lo que queremos buscar son los puntos_negros**

# %%
df_unicas = df.drop_duplicates(subset='accidente_id')
print(df_unicas)
# Out:
#         accidente_id      fecha  rango_horario  \
# 0        2010.135000 2010-01-01              0
# 3        2010.940000 2010-01-01              1
# 11       2010.700000 2010-01-01              2
# 13       2010.400000 2010-01-01              4
# 24       2010.172000 2010-01-01              5
# ...              ...        ...            ...
# 478774   2024.004340 2024-01-18             12
# 478776   2024.004634 2024-01-30             18
# 478778   2024.004705 2024-01-31              9
# 478780   2024.005341 2024-01-27             13
# 478782   2024.006301 2024-01-29             21
#
#                                              localizacion numero  \
# 0       calle de cartagena                            ...     14
# 3       autovia  m-30 calzada 2 km.                   ...     12
# 11      glorieta de emilio castelar - paseo de la cast...
# 13      autovia  m-30 calzada 1 km.                   ...     85
# 24      calle de o'donnell - calle del doctor esquerdo...
# ...                                                   ...    ...
# 478774                                             madrid     19
# 478776  calle benjamin palencia - calle fuente carrantona     64
# 478778       calle virgen de lluc - calle buen gobernador     12
# 478780                                 paseo. juan xxiii      16
# 478782                           avda. monforte de lemos     172
#
#                    distrito  coordenada_x  coordenada_y     condicion  \
# 0                 chamartin           NaN           NaN  desfavorable
# 3        puente de vallecas           NaN           NaN     favorable
# 11                 chamberi           NaN           NaN     favorable
# 13                   retiro           NaN           NaN     favorable
# 24                salamanca           NaN           NaN     favorable
# ...                     ...           ...           ...           ...
# 478774             chamberi    440956.827   4476794.579     favorable
# 478776   puente de vallecas    445613.297   4471683.953     favorable
# 478778        ciudad lineal    444464.372   4476185.781     favorable
# 478780             chamberi    439084.688   4477567.644     favorable
# 478782  fuencarral-el pardo    439356.877   4480962.780     favorable
#
#                                lesividad  ... positiva_alcohol  \
# 0                   ingreso inferior 24h  ...              NaN
# 3       asistencia sanitaria sin ingreso  ...              NaN
# 11      asistencia sanitaria sin ingreso  ...              NaN
# 13                  ingreso inferior 24h  ...              NaN
# 24      asistencia sanitaria sin ingreso  ...              NaN
# ...                                  ...  ...              ...
# 478774                               NaN  ...              0.0
# 478776                               NaN  ...              0.0
# 478778  asistencia sanitaria sin ingreso  ...              0.0
# 478780                               NaN  ...              0.0
# 478782                               NaN  ...              0.0
#
#         positiva_droga  rango_edad    sexo     tipo_accidente  \
# 0                  NaN         5.0  hombre     colision doble
# 3                  NaN         7.0   mujer  colision multiple
# 11                 NaN         9.0  hombre     colision doble
# 13                 NaN         7.0  hombre  colision multiple
# 24                 NaN        14.0  hombre     colision doble
# ...                ...         ...     ...                ...
# 478774             NaN        11.0  hombre     colision doble
# 478776             NaN        14.0  hombre     colision doble
# 478778             NaN         8.0  hombre     colision doble
# 478780             NaN         7.0   mujer     colision doble
# 478782             NaN         9.0  hombre       otras causas
#
#           tipo_vehiculo victimas  \
# 0               turismo      1.0
# 3                   NaN      7.0
# 11          motocicleta      1.0
# 13                  NaN      7.0
# 24              turismo      1.0
# ...                 ...      ...
# 478774          turismo      NaN
# 478776  autobus-autocar      NaN
# 478778        bicicleta      NaN
# 478780          turismo      NaN
# 478782          turismo      NaN
#
#                                     localizacion_completa  \
# 0       calle de cartagena                            ...
# 3       autovia  m-30 calzada 2 km.                   ...
# 11      glorieta de emilio castelar - paseo de la cast...
# 13      autovia  m-30 calzada 1 km.                   ...
# 24      calle de o'donnell - calle del doctor esquerdo...
# ...                                                   ...
# 478774                                         madrid, 19
# 478776  calle benjamin palencia - calle fuente carrant...
# 478778   calle virgen de lluc - calle buen gobernador, 12
# 478780                             paseo. juan xxiii , 16
# 478782                      avda. monforte de lemos , 172
#
#                                               direccion_1  \
# 0       calle de cartagena                            ...
# 3       autovia  m-30 calzada 2 km.                   ...
# 11                            glorieta de emilio castelar
# 13      autovia  m-30 calzada 1 km.                   ...
# 24                                     calle de o'donnell
# ...                                                   ...
# 478774                                             madrid
# 478776                            calle benjamin palencia
# 478778                               calle virgen de lluc
# 478780                                 paseo. juan xxiii
# 478782                           avda. monforte de lemos
#
#                                               direccion_2
# 0                                                    None
# 3                                                    None
# 11      paseo de la castellana                        ...
# 13                                                   None
# 24      calle del doctor esquerdo                     ...
# ...                                                   ...
# 478774                                               None
# 478776                            calle fuente carrantona
# 478778                              calle buen gobernador
# 478780                                               None
# 478782                                               None
#
# [176487 rows x 21 columns]

# %% [markdown]
# **A continuación lo que vamos a hacer es ver es en que puntos se repiten los accidentes en Madrid**
#
# Para ello vamos a contar las veces que se repite localizacion_completa, que es el lugar exacto del accidente.
# Y vamos a crear una nueva columna que se llama puntos_negros para que cuente las veces que existen accidentes en ese punto

# %%
# Paso 1: Contamos los valores repetidos en 'localizacion_completa'
conteo_direcciones = df_unicas['localizacion_completa'].value_counts()

# Paso 2: Unir la suma de direcciones de df_unicas basado en 'localizacion_completa'
df_unicas = df_unicas.merge(conteo_direcciones.rename('punto_negro'), left_on='localizacion_completa', right_index=True)

# Paso 3: Crear df_puntos_negros con todas las columnas de df_unicas y ordenarlo por 'punto_negro'
df_puntos_negros = df_unicas.copy()
df_puntos_negros = df_puntos_negros.sort_values(by='punto_negro', ascending=False)

df_puntos_negros
# Out:
#         accidente_id      fecha  rango_horario  \
# 105052   2013.107380 2013-12-01             20
# 54211    2012.217000 2012-01-05             18
# 203286   2017.447800 2017-05-11             23
# 213460   2017.877300 2017-09-20             21
# 252919   2018.166570 2018-12-30              0
# ...              ...        ...            ...
# 359217   2021.013625 2021-07-30             12
# 225439   2018.116400 2018-01-30             14
# 225435   2018.115200 2018-01-30             13
# 359228   2021.013628 2021-07-30             13
# 272965   2019.021731 2019-05-21             18
#
#                                              localizacion numero  \
# 105052  paseo de la castellana - plaza de lima        ...
# 54211   paseo de la castellana - plaza de lima        ...
# 203286  paseo de la castellana - plaza de lima        ...
# 213460  paseo de la castellana - plaza de lima        ...
# 252919  paseo de la castellana - plaza de lima        ...
# ...                                                   ...    ...
# 359217          autov. m-30 +00000e m-30 calzada 2ª pk 0.     +e
# 225439  calle de villablanca                          ...      1
# 225435  calle de marcelo usera                        ...     87
# 359228                    calle almaden - calle san pedro      6
# 272965                               avenida de andalucia      1
#
#              distrito  coordenada_x  coordenada_y  condicion  \
# 105052         tetuan           NaN           NaN  favorable
# 54211          tetuan           NaN           NaN  favorable
# 203286      chamartin           NaN           NaN  favorable
# 213460         tetuan           NaN           NaN  favorable
# 252919      chamartin           NaN           NaN  favorable
# ...               ...           ...           ...        ...
# 359217  ciudad lineal    442883.453   4481279.846        NaN
# 225439      vicalvaro           NaN           NaN  favorable
# 225435          usera           NaN           NaN  favorable
# 359228         centro    441042.895   4473621.725  favorable
# 272965     villaverde    441143.160   4466996.510  favorable
#
#                                lesividad  ... positiva_droga  rango_edad  \
# 105052              ingreso superior 24h  ...            NaN         8.0
# 54211   asistencia sanitaria sin ingreso  ...            NaN        15.0
# 203286  asistencia sanitaria sin ingreso  ...            NaN         9.0
# 213460  asistencia sanitaria sin ingreso  ...            NaN         8.0
# 252919              ingreso inferior 24h  ...            NaN         9.0
# ...                                  ...  ...            ...         ...
# 359217          sin asistencia sanitaria  ...            NaN         7.0
# 225439  asistencia sanitaria sin ingreso  ...            NaN         7.0
# 225435              ingreso superior 24h  ...            NaN         2.0
# 359228          sin asistencia sanitaria  ...            NaN        12.0
# 272965                               NaN  ...            NaN         9.0
#
#           sexo          tipo_accidente           tipo_vehiculo victimas  \
# 105052  hombre               atropello                     NaN      1.0
# 54211   hombre               atropello                     NaN      2.0
# 203286  hombre          colision doble              ciclomotor      1.0
# 213460   mujer          colision doble                 turismo      2.0
# 252919  hombre          colision doble                 turismo      1.0
# ...        ...                     ...                     ...      ...
# 359217  hombre          colision doble                  camion      NaN
# 225439  hombre  choque con objeto fijo                 turismo      1.0
# 225435  hombre               atropello                     NaN      1.0
# 359228  hombre          colision doble                 turismo      NaN
# 272965  hombre            otras causas  furgoneta-autocaravana      NaN
#
#                                     localizacion_completa  \
# 105052  paseo de la castellana - plaza de lima        ...
# 54211   paseo de la castellana - plaza de lima        ...
# 203286  paseo de la castellana - plaza de lima        ...
# 213460  paseo de la castellana - plaza de lima        ...
# 252919  paseo de la castellana - plaza de lima        ...
# ...                                                   ...
# 359217      autov. m-30 +00000e m-30 calzada 2ª pk 0., +e
# 225439  calle de villablanca                          ...
# 225435  calle de marcelo usera                        ...
# 359228                 calle almaden - calle san pedro, 6
# 272965                            avenida de andalucia, 1
#
#                                               direccion_1  \
# 105052                             paseo de la castellana
# 54211                              paseo de la castellana
# 203286                             paseo de la castellana
# 213460                             paseo de la castellana
# 252919                             paseo de la castellana
# ...                                                   ...
# 359217          autov. m-30 +00000e m-30 calzada 2ª pk 0.
# 225439  calle de villablanca                          ...
# 225435  calle de marcelo usera                        ...
# 359228                                      calle almaden
# 272965                               avenida de andalucia
#
#                                               direccion_2 punto_negro
# 105052  plaza de lima                                 ...         132
# 54211   plaza de lima                                 ...         132
# 203286  plaza de lima                                 ...         132
# 213460  plaza de lima                                 ...         132
# 252919  plaza de lima                                 ...         132
# ...                                                   ...         ...
# 359217                                               None           1
# 225439                                               None           1
# 225435                                               None           1
# 359228                                    calle san pedro           1
# 272965                                               None           1
#
# [176487 rows x 22 columns]

# %% [markdown]
# **Aquí lo que hacemos es utilizando la columna de puntos negros ordenarlos por años, así vemos cada año donde es
# el lugar de top de punto negro y ordenado por barrio**
#
# Como hay muchos datos que no nos van a interesar para nada le digo que me coja como mucho 1.000 datos por barrio,
# siendo el mínimo 30. Habrá barrios donde hay menos puntos negros...

# %%
resultados = []

for año in range(2010, 2024):
    df_año = df_puntos_negros[df_puntos_negros['fecha'].dt.year == año]
    
    # Esto es para ordenar por 'punto_negro' de manera descendente
    df_año_ordenado = df_año.sort_values(by='punto_negro', ascending=False)
        
    registros_seleccionados = []
    
    # Agrupamos
    for distrito, grupo in df_año_ordenado.groupby('distrito'):
        registros_distrito = grupo.head(30)  # Aquí le decimos que coja los 30 primeros de cada distrito (si los hay)
        registros_seleccionados.append(registros_distrito)
    
    # Combinamos
    df_seleccionados = pd.concat(registros_seleccionados).drop_duplicates().head(1000)  # Limitamos a 1.000 registros, no queremos más para nada
    resultados.append(df_seleccionados)

# Combinamos todo
df_resultado_final = pd.concat(resultados)

# Y para el año 2024 como habían muy pocos, pues los añadimos todos
df_2024 = df_puntos_negros[df_puntos_negros['fecha'].dt.year == 2024]
df_resultado_final = pd.concat([df_resultado_final, df_2024])

df_resultado_final
# Out:
#         accidente_id      fecha  rango_horario  \
# 22083    2010.995700 2010-11-09              4
# 6062     2010.296200 2010-03-31             16
# 174      2010.153000 2010-01-04             16
# 20271    2010.922200 2010-10-19              9
# 19168    2010.874500 2010-10-03             23
# ...              ...        ...            ...
# 476601   2024.001546 2024-01-15             17
# 476603   2024.001547 2024-01-15             20
# 476605   2024.001548 2024-01-15             19
# 476607   2024.001550 2024-01-15             20
# 476615   2024.001555 2024-01-15             21
#
#                                              localizacion numero    distrito  \
# 22083   autovia  m-30 calzada 1 km.                   ...     12  arganzuela
# 6062    autovia  m-30 calzada 1 km.                   ...     12  arganzuela
# 174     autovia  m-30 calzada 1 km.                   ...     12  arganzuela
# 20271   autovia  m-30 calzada 1 km.                   ...     12  arganzuela
# 19168   autovia  m-30 calzada 1 km.                   ...     12  arganzuela
# ...                                                   ...    ...         ...
# 476601                               plaza. gabriel miro       7      centro
# 476603                             calle nuñez de balboa      86   salamanca
# 476605                          calle vigil - calle boyer     2a   vicalvaro
# 476607                                   autov. m-30 09nc   9nc7      retiro
# 476615               calle doctor esquerdo - calle moneda     66      retiro
#
#         coordenada_x  coordenada_y     condicion  \
# 22083            NaN           NaN  desfavorable
# 6062             NaN           NaN     favorable
# 174              NaN           NaN  desfavorable
# 20271            NaN           NaN     favorable
# 19168            NaN           NaN  desfavorable
# ...              ...           ...           ...
# 476601    439330.129   4473727.919           NaN
# 476603    442146.054   4476054.421     favorable
# 476605    450240.390   4472879.964  desfavorable
# 476607    443468.671   4472932.015  desfavorable
# 476615    443182.311   4473973.169           NaN
#
#                                lesividad  ... positiva_droga  rango_edad  \
# 22083   asistencia sanitaria sin ingreso  ...            NaN         9.0
# 6062    asistencia sanitaria sin ingreso  ...            NaN         7.0
# 174     asistencia sanitaria sin ingreso  ...            NaN         6.0
# 20271               ingreso inferior 24h  ...            NaN        11.0
# 19168   asistencia sanitaria sin ingreso  ...            NaN         6.0
# ...                                  ...  ...            ...         ...
# 476601                               NaN  ...            NaN         8.0
# 476603                               NaN  ...            NaN        11.0
# 476605  asistencia sanitaria sin ingreso  ...            NaN        10.0
# 476607  asistencia sanitaria sin ingreso  ...            NaN        13.0
# 476615                               NaN  ...            NaN         9.0
#
#           sexo          tipo_accidente tipo_vehiculo victimas  \
# 22083   hombre  choque con objeto fijo       turismo      1.0
# 6062    hombre          colision doble       turismo      1.0
# 174      mujer  choque con objeto fijo       turismo      1.0
# 20271   hombre       colision multiple       turismo      3.0
# 19168    mujer  choque con objeto fijo       turismo      1.0
# ...        ...                     ...           ...      ...
# 476601   mujer          colision doble       turismo      NaN
# 476603   mujer          colision doble       turismo      NaN
# 476605  hombre          colision doble   motocicleta      NaN
# 476607  hombre          colision doble   motocicleta      NaN
# 476615  hombre          colision doble       turismo      NaN
#
#                                     localizacion_completa  \
# 22083   autovia  m-30 calzada 1 km.                   ...
# 6062    autovia  m-30 calzada 1 km.                   ...
# 174     autovia  m-30 calzada 1 km.                   ...
# 20271   autovia  m-30 calzada 1 km.                   ...
# 19168   autovia  m-30 calzada 1 km.                   ...
# ...                                                   ...
# 476601                            plaza. gabriel miro , 7
# 476603                         calle nuñez de balboa , 86
# 476605                      calle vigil - calle boyer, 2a
# 476607                             autov. m-30 09nc, 9nc7
# 476615           calle doctor esquerdo - calle moneda, 66
#
#                                               direccion_1   direccion_2  \
# 22083   autovia  m-30 calzada 1 km.                   ...          None
# 6062    autovia  m-30 calzada 1 km.                   ...          None
# 174     autovia  m-30 calzada 1 km.                   ...          None
# 20271   autovia  m-30 calzada 1 km.                   ...          None
# 19168   autovia  m-30 calzada 1 km.                   ...          None
# ...                                                   ...           ...
# 476601                               plaza. gabriel miro           None
# 476603                             calle nuñez de balboa           None
# 476605                                        calle vigil   calle boyer
# 476607                                   autov. m-30 09nc          None
# 476615                              calle doctor esquerdo  calle moneda
#
#        punto_negro
# 22083           64
# 6062            64
# 174             64
# 20271           64
# 19168           64
# ...            ...
# 476601           1
# 476603           1
# 476605           1
# 476607           1
# 476615           1
#
# [10462 rows x 22 columns]

# %%
# Vamos a mirar por ejemplo en el distrito centro los resultados para ver si ha funcionado bien. 
df_centro = df_resultado_final.loc[df_resultado_final['distrito'] == 'centro']

# Mostrar los resultados para el distrito 'Centro'
df_centro

# Por ejemplo aquí podemos ver ha cogido 520 datos.
# Out:
#         accidente_id      fecha  rango_horario  \
# 10695    2010.496300 2010-06-01             11
# 23468    2010.106250 2010-11-24             14
# 17472    2010.792600 2010-09-09             15
# 12989    2010.592200 2010-06-29             20
# 10321    2010.480100 2010-05-27             16
# ...              ...        ...            ...
# 476618   2024.001558 2024-01-15             20
# 476573   2024.001532 2024-01-15             17
# 476587   2024.001538 2024-01-15             18
# 476593   2024.001542 2024-01-15             20
# 476601   2024.001546 2024-01-15             17
#
#                                              localizacion numero distrito  \
# 10695   calle de alcala - plaza de cibeles            ...          centro
# 23468   paseo del prado - plaza de canovas del castill...          centro
# 17472   plaza del emperador carlos v                  ...      1   centro
# 12989   plaza del emperador carlos v                  ...      1   centro
# 10321   plaza del emperador carlos v                  ...      1   centro
# ...                                                   ...    ...      ...
# 476618             calle meson de paredes - calle juanelo      7   centro
# 476573                                       calle angel      19   centro
# 476587              calle don pedro - plaza. gabriel miro      2   centro
# 476593                        calle ribera de curtidores      24   centro
# 476601                               plaza. gabriel miro       7   centro
#
#         coordenada_x  coordenada_y     condicion             lesividad  ...  \
# 10695            NaN           NaN     favorable  ingreso inferior 24h  ...
# 23468            NaN           NaN     favorable  ingreso inferior 24h  ...
# 17472            NaN           NaN     favorable  ingreso inferior 24h  ...
# 12989            NaN           NaN     favorable  ingreso inferior 24h  ...
# 10321            NaN           NaN     favorable  ingreso inferior 24h  ...
# ...              ...           ...           ...                   ...  ...
# 476618    440178.731   4473657.333  desfavorable                   NaN  ...
# 476573    439511.276   4473493.190  desfavorable                   NaN  ...
# 476587    439353.596   4473734.854           NaN                   NaN  ...
# 476593    439985.807   4473205.539  desfavorable                   NaN  ...
# 476601    439330.129   4473727.919           NaN                   NaN  ...
#
#        positiva_droga  rango_edad    sexo          tipo_accidente  \
# 10695             NaN        10.0  hombre          colision doble
# 23468             NaN        11.0  hombre       colision multiple
# 17472             NaN         9.0   mujer          colision doble
# 12989             NaN         8.0  hombre          colision doble
# 10321             NaN         8.0  hombre          colision doble
# ...               ...         ...     ...                     ...
# 476618            NaN         6.0  hombre          colision doble
# 476573            NaN         7.0  hombre          colision doble
# 476587            NaN         8.0  hombre  choque con objeto fijo
# 476593            NaN        11.0  hombre          colision doble
# 476601            NaN         8.0   mujer          colision doble
#
#        tipo_vehiculo victimas  \
# 10695            NaN      1.0
# 23468        turismo      1.0
# 17472        turismo      1.0
# 12989        turismo      1.0
# 10321        turismo      1.0
# ...              ...      ...
# 476618     bicicleta      NaN
# 476573       turismo      NaN
# 476587       turismo      NaN
# 476593       turismo      NaN
# 476601       turismo      NaN
#
#                                     localizacion_completa  \
# 10695   calle de alcala - plaza de cibeles            ...
# 23468   paseo del prado - plaza de canovas del castill...
# 17472   plaza del emperador carlos v                  ...
# 12989   plaza del emperador carlos v                  ...
# 10321   plaza del emperador carlos v                  ...
# ...                                                   ...
# 476618          calle meson de paredes - calle juanelo, 7
# 476573                                   calle angel , 19
# 476587           calle don pedro - plaza. gabriel miro, 2
# 476593                    calle ribera de curtidores , 24
# 476601                            plaza. gabriel miro , 7
#
#                                               direccion_1  \
# 10695                                     calle de alcala
# 23468                                     paseo del prado
# 17472   plaza del emperador carlos v                  ...
# 12989   plaza del emperador carlos v                  ...
# 10321   plaza del emperador carlos v                  ...
# ...                                                   ...
# 476618                             calle meson de paredes
# 476573                                       calle angel
# 476587                                    calle don pedro
# 476593                        calle ribera de curtidores
# 476601                               plaza. gabriel miro
#
#                                               direccion_2 punto_negro
# 10695   plaza de cibeles                              ...          84
# 23468   plaza de canovas del castillo                 ...          76
# 17472                                                None          71
# 12989                                                None          71
# 10321                                                None          71
# ...                                                   ...         ...
# 476618                                      calle juanelo           1
# 476573                                               None           1
# 476587                                plaza. gabriel miro           1
# 476593                                               None           1
# 476601                                               None           1
#
# [520 rows x 22 columns]

# %% [markdown]
# **Ahora lo que vamos a hacer es agrupar por localización_completa y ordenamos por punto_negro**
#
# Pero vamos a crear una nueva columna que nos haga de ranking del primero como punto negro hasta el menor

# %%
# Primero: Agrupamos por 'localizacion_completa'
agregaciones = {
    'punto_negro': 'max',
    'accidente_id': 'first',
    'fecha': 'first',
    'rango_horario': 'first',
    'localizacion': 'first',
    'numero': 'first',
    'distrito': 'first',
    'coordenada_x': 'first',
    'coordenada_y': 'first',
    'condicion': 'first',
    'lesividad': 'first',
    'persona_implicada': 'first',
    'positiva_alcohol': 'first',
    'positiva_droga': 'first',
    'rango_edad': 'first',
    'sexo': 'first',
    'tipo_accidente': 'first',
    'tipo_vehiculo': 'first',
    'victimas': 'first',
    'direccion_1': 'first',
    'direccion_2': 'first'
}

df_agrupado = df_resultado_final.groupby('localizacion_completa', as_index=False).agg(agregaciones)

# Segundo: Ordenamos por 'punto_negro' de manera descendente
df_agrupado = df_agrupado.sort_values(by='punto_negro', ascending=False)

# Tercero: Creams la columna 'ranking_punto_negro'
df_agrupado['ranking_punto_negro'] = range(1, len(df_agrupado) + 1)

df_agrupado

#Así tenemos ordenados del punto más peligroso de Madrid hacia menos... aunque siguen siendo punto negro
# Out:
#                                   localizacion_completa  punto_negro  \
# 1865  paseo de la castellana - plaza de lima        ...          132
# 64                            autov. m-30 +01100i, +11i          121
# 11                              autov. a-2 +00500e, +5e          118
# 1734  complejo  aeropuerto de barajas               ...          116
# 1864  paseo de la castellana - plaza de cuzco       ...          112
# ...                                                 ...          ...
# 1090                            calle eugenio d'ors , 2            1
# 1088       calle estrella polar - calle pez austral, 24            1
# 1087               calle estrella hadar - calle eros, 6            1
# 1086                               calle estefanita , 3            1
# 2084             tunel azca planta -1 07 t-azc 1º  , 89            1
#
#       accidente_id      fecha  rango_horario  \
# 1865   2010.506300 2010-06-05             21
# 64     2019.017297 2019-03-27             12
# 11     2019.037143 2019-11-29             22
# 1734   2010.331000 2010-01-12              8
# 1864   2010.138200 2010-02-12             13
# ...            ...        ...            ...
# 1090   2024.000251 2024-01-04             17
# 1088   2024.000800 2024-01-10              7
# 1087   2024.003595 2024-01-31             15
# 1086   2024.001504 2024-01-14             20
# 2084   2024.000820 2024-01-10             12
#
#                                            localizacion numero       distrito  \
# 1865  paseo de la castellana - plaza de lima        ...             chamartin
# 64                                  autov. m-30 +01100i   +11i     arganzuela
# 11                                   autov. a-2 +00500e    +5e  ciudad lineal
# 1734  complejo  aeropuerto de barajas               ...               barajas
# 1864  paseo de la castellana - plaza de cuzco       ...             chamartin
# ...                                                 ...    ...            ...
# 1090                               calle eugenio d'ors       2      moratalaz
# 1088           calle estrella polar - calle pez austral     24         retiro
# 1087                  calle estrella hadar - calle eros      6     arganzuela
# 1086                                  calle estefanita       3     villaverde
# 2084                 tunel azca planta -1 07 t-azc 1º       89         tetuan
#
#       coordenada_x  coordenada_y  ... positiva_alcohol positiva_droga  \
# 1865           NaN           NaN  ...              NaN            NaN
# 64      442724.319   4471669.860  ...              0.0            NaN
# 11      444536.890   4477584.100  ...              0.0            NaN
# 1734           NaN           NaN  ...              NaN            NaN
# 1864           NaN           NaN  ...              NaN            NaN
# ...            ...           ...  ...              ...            ...
# 1090    444309.357   4473661.560  ...              0.0            NaN
# 1088    443533.577   4473608.565  ...              0.0            NaN
# 1087    442272.212   4471688.482  ...              0.0            NaN
# 1086    442600.472   4466540.705  ...              0.0            NaN
# 2084    441313.457   4477963.711  ...              0.0            NaN
#
#      rango_edad    sexo          tipo_accidente           tipo_vehiculo  \
# 1865        5.0   mujer          colision doble                 turismo
# 64         11.0  hombre       colision multiple  furgoneta-autocaravana
# 11          7.0   mujer       colision multiple                 turismo
# 1734        8.0   mujer  choque con objeto fijo                 turismo
# 1864        7.0   mujer       colision multiple                 turismo
# ...         ...     ...                     ...                     ...
# 1090        NaN    None          colision doble                 turismo
# 1088        8.0  hombre          colision doble             motocicleta
# 1087       10.0   mujer          colision doble                 turismo
# 1086        9.0   mujer               atropello                 turismo
# 2084       12.0  hombre          colision doble              ciclomotor
#
#      victimas                                        direccion_1  \
# 1865      2.0                             paseo de la castellana
# 64        NaN                                autov. m-30 +01100i
# 11        NaN                                 autov. a-2 +00500e
# 1734      1.0  complejo  aeropuerto de barajas               ...
# 1864      2.0                             paseo de la castellana
# ...       ...                                                ...
# 1090      NaN                               calle eugenio d'ors
# 1088      NaN                               calle estrella polar
# 1087      NaN                               calle estrella hadar
# 1086      NaN                                  calle estefanita
# 2084      NaN                 tunel azca planta -1 07 t-azc 1º
#
#                                             direccion_2  ranking_punto_negro
# 1865  plaza de lima                                 ...                    1
# 64                                                 None                    2
# 11                                                 None                    3
# 1734                                               None                    4
# 1864  plaza de cuzco                                ...                    5
# ...                                                 ...                  ...
# 1090                                               None                 2081
# 1088                                  calle pez austral                 2082
# 1087                                         calle eros                 2083
# 1086                                               None                 2084
# 2084                                               None                 2085
#
# [2085 rows x 23 columns]

# %% [markdown]
# **Aquí contamos los valores NaN para saber las coordenadas que tenemos que buscar**

# %%
nan_coordenada_x = df_resultado_final['coordenada_x'].isna().sum()
nan_coordenada_y = df_resultado_final['coordenada_y'].isna().sum()

print(f"Número de valores NaN en 'coordenada_x': {nan_coordenada_x}")
print(f"Número de valores NaN en 'coordenada_y': {nan_coordenada_y}")
# Out:
# Número de valores NaN en 'coordenada_x': 5672
# Número de valores NaN en 'coordenada_y': 5672

# %% [markdown]
# # Ojo que tarda al ejecutar
# ## No ejecutar si no se quiere estar un buen rato esperando...
#
# **Creamos diferentes funciones para a través de geocoder (pip install geocoder) buscar las coordenadas en UTM que son
# las que existe en nuestro dataframe.**
#
# Hacemos un bucle y que itere en cada fila que no contenga ya coordenada (que son principalmente del año 2010 al 2018).
# Es importante destacar que es probable que no encuentre alguna coordenada.
# Lo que hacemos en el for es buscar primero en localizacion_completa. En caso de no encontrar que busque direccion_1 y direccion_2 la coordenada y haga como un cruce de coordenadas, y en caso de no encontrar tampoco que busque en
# direccion_1 + columna numero.
#
# Como se repetía el proceso para direcciones que eran iguales, lo que hacemos es reducir a direcciones únicas y luego que las copie al resto que sean iguales las coordenadas. Para ahorrar tiempo.

# %%
def obtener_coordenadas_calle(direccion):
    g = geocoder.osm(direccion)
    if g.ok:
        return g.lat, g.lng
    return None, None

def buscar_coordenadas_utm_geocoder(direccion):
    lat, lng = obtener_coordenadas_calle(direccion)
    if lat and lng:
        utm_coords = utm.from_latlon(lat, lng)
        return utm_coords[0], utm_coords[1]
    return None, None

def estimar_punto_cruce(calle1, calle2, distrito):
    direccion1 = f"{calle1}, {distrito}, Madrid, Spain"
    direccion2 = f"{calle2}, {distrito}, Madrid, Spain"
    
    lat1, lng1 = obtener_coordenadas_calle(direccion1)
    lat2, lng2 = obtener_coordenadas_calle(direccion2)
    
    if lat1 and lat2 and lng1 and lng2:
        lat_cruce = (lat1 + lat2) / 2
        lng_cruce = (lng1 + lng2) / 2
        utm_cruce = utm.from_latlon(lat_cruce, lng_cruce)
        return utm_cruce[0], utm_cruce[1]
    return None, None

# Creamos un nuevo df con las columnas que nos interesan
df_unicas = df_resultado_final[['localizacion_completa', 'distrito', 'direccion_1', 'direccion_2', 'numero', 'coordenada_x', 'coordenada_y']].drop_duplicates(subset='localizacion_completa')

# Iteramos sobre df_unicas para buscar y actualizar coordenadas donde sea necesario (donde haya Nan)
for index, row in df_unicas.iterrows():
    if pd.isna(row['coordenada_x']) or pd.isna(row['coordenada_y']):
        # Primero buscará 'localizacion_completa'
        coordenada_x, coordenada_y = buscar_coordenadas_utm_geocoder(f"{row['localizacion_completa']}, {row['distrito']}, Madrid, Spain")
        if coordenada_x is not None and coordenada_y is not None:
            print(f"Coordenada encontrada para {row['localizacion_completa']}")
            df_resultado_final.at[index, 'coordenada_x'] = coordenada_x
            df_resultado_final.at[index, 'coordenada_y'] = coordenada_y
        else:
            print(f"Coordenada no encontrada para {row['localizacion_completa']}, intentando con cruce...")

            # Si no lo encuentra, irá a buscar entre el cruce entre 'direccion_1' y 'direccion_2'
            if pd.notna(row['direccion_2']):
                coordenada_x, coordenada_y = estimar_punto_cruce(row['direccion_1'], row['direccion_2'], row['distrito'])
                if coordenada_x is not None and coordenada_y is not None:
                    print(f"Coordenada encontrada para cruce entre {row['direccion_1']} y {row['direccion_2']}")
                    df_resultado_final.at[index, 'coordenada_x'] = coordenada_x
                    df_resultado_final.at[index, 'coordenada_y'] = coordenada_y
                else:
                    print(f"Coordenada no encontrada para cruce, intentando con 'direccion_1' y 'numero'...")

            # Y si no lo encuentra, probamos una última opción de búsqueda que es buscar con 'direccion_1' + 'numero'
            if coordenada_x is None or coordenada_y is None:
                direccion_final = f"{row['direccion_1']}"
                if pd.notna(row['numero']):
                    direccion_final += f" {row['numero']}"
                direccion_final += f", {row['distrito']}, Madrid, Spain"
                coordenada_x, coordenada_y = buscar_coordenadas_utm_geocoder(direccion_final)
                if coordenada_x is not None and coordenada_y is not None:
                    print(f"Coordenada encontrada para {direccion_final}")
                    df_resultado_final.at[index, 'coordenada_x'] = coordenada_x
                    df_resultado_final.at[index, 'coordenada_y'] = coordenada_y
                else:
                    print(f"Coordenada finalmente no encontrada para {direccion_final}")


# Guardamos df_unicas con las coordenadas en un archivo pickle para no tener que ejecutar este paso que tarda mucho
df_unicas.to_pickle('mapas/df_coordenadas.pkl')
# Out:
# Coordenada no encontrada para autovia  m-30 calzada 1 km.                                                                         , 12, intentando con cruce...
# Coordenada finalmente no encontrada para autovia  m-30 calzada 1 km.                                                                          12, arganzuela, Madrid, Spain
# Coordenada no encontrada para autovia  m-30 calzada 1 km.                                                                         , 17, intentando con cruce...
# Coordenada finalmente no encontrada para autovia  m-30 calzada 1 km.                                                                          17, arganzuela, Madrid, Spain
# Coordenada no encontrada para autovia  m-30 calzada 1 km.                                                                         , 11, intentando con cruce...
# Coordenada finalmente no encontrada para autovia  m-30 calzada 1 km.                                                                          11, arganzuela, Madrid, Spain
# Coordenada no encontrada para calle de segovia - paseo de la virgen del puerto                                                    , intentando con cruce...
# Coordenada encontrada para cruce entre calle de segovia y paseo de la virgen del puerto
# Coordenada no encontrada para autovia  m-30 calzada 1 km.                                                                         , 18, intentando con cruce...
# Coordenada finalmente no encontrada para autovia  m-30 calzada 1 km.                                                                          18, arganzuela, Madrid, Spain
# Coordenada no encontrada para avenida del planetario - calle de mendez alvaro                                                     , intentando con cruce...
# Coordenada encontrada para cruce entre avenida del planetario y calle de mendez alvaro
# Coordenada encontrada para avenida de la ciudad de barcelona                                                                , 2
# Coordenada encontrada para paseo de santa maria de la cabeza                                                                , 1
# Coordenada no encontrada para complejo  aeropuerto de barajas                                                                     , intentando con cruce...
# Coordenada finalmente no encontrada para complejo  aeropuerto de barajas                                                                      , barajas, Madrid, Spain
# Coordenada encontrada para glorieta de la ermita de la virgen de la soledad
# Coordenada no encontrada para aeropuerto terminal t -                                                                             , 4, intentando con cruce...
# Coordenada no encontrada para cruce, intentando con 'direccion_1' y 'numero'...
# Coordenada finalmente no encontrada para aeropuerto terminal t 4, barajas, Madrid, Spain
# Coordenada no encontrada para parque de juan carlos i                                                                          , 1, intentando con cruce...
# Coordenada finalmente no encontrada para parque de juan carlos i                                                                           1, barajas, Madrid, Spain
# Coordenada encontrada para avenida de la hispanidad                                                                         , 2
# Coordenada no encontrada para autovia  m-40 - avenida de logroño                                                                  , intentando con cruce...
# Coordenada no encontrada para cruce, intentando con 'direccion_1' y 'numero'...
# Coordenada finalmente no encontrada para autovia  m-40 , barajas, Madrid, Spain
# Coordenada no encontrada para aeropuerto terminal t-                                                                              , 1, intentando con cruce...
# Coordenada finalmente no encontrada para aeropuerto terminal t-                                                                               1, barajas, Madrid, Spain
# Coordenada encontrada para avenida de logroño                                                                               , 34
# Coordenada encontrada para avenida de la hispanidad                                                                         , 6
# Coordenada encontrada para calle de la ribera del loira                                                                     , 28
# Coordenada no encontrada para avenida de logroño - calle de los jardines de aranjuez                                              , intentando con cruce...
# Coordenada encontrada para cruce entre avenida de logroño y calle de los jardines de aranjuez
# Coordenada no encontrada para calle de manuel aguilar muñoz - paseo de la alameda de osuna                                        , intentando con cruce...
# Coordenada encontrada para cruce entre calle de manuel aguilar muñoz y paseo de la alameda de osuna
# Coordenada no encontrada para avenida de la capital de españa madrid - avenida del partenon                                       , intentando con cruce...
# Coordenada encontrada para cruce entre avenida de la capital de españa madrid y avenida del partenon
# Coordenada no encontrada para calle de la corbeta - calle de la rioja                                                             , intentando con cruce...
# Coordenada encontrada para cruce entre calle de la corbeta y calle de la rioja
# Coordenada no encontrada para avenida de la princesa juana de austria - avenida de los poblados                                   , intentando con cruce...
# Coordenada encontrada para cruce entre avenida de la princesa juana de austria y avenida de los poblados
# Coordenada no encontrada para avenida de los poblados - calle de eugenia de montijo                                               , intentando con cruce...
# Coordenada encontrada para cruce entre avenida de los poblados y calle de eugenia de montijo
# Coordenada no encontrada para avenida de los poblados - calle  via lusitana                                                       , intentando con cruce...
# Coordenada encontrada para cruce entre avenida de los poblados y calle  via lusitana
# Coordenada no encontrada para avenida de los poblados - avenida de la princesa juana de austria                                   , intentando con cruce...
# Coordenada encontrada para cruce entre avenida de los poblados y avenida de la princesa juana de austria
# Coordenada encontrada para avenida de oporto - calle del camino viejo de leganes
# Coordenada encontrada para calle  via lusitana                                                                              , 1
# Coordenada no encontrada para avenida de los poblados - calle de belzunegui                                                       , intentando con cruce...
# Coordenada encontrada para cruce entre avenida de los poblados y calle de belzunegui
# Coordenada encontrada para avenida de los poblados                                                                          , 1
# Coordenada no encontrada para avenida de los poblados - avenida del euro                                                          , intentando con cruce...
# Coordenada encontrada para cruce entre avenida de los poblados y avenida del euro
# Coordenada no encontrada para calle  via lusitana - calle de braganza                                                             , intentando con cruce...
# Coordenada encontrada para cruce entre calle  via lusitana y calle de braganza
# Coordenada no encontrada para avenida de la princesa juana de austria km.                                                         , 42, intentando con cruce...
# Coordenada encontrada para avenida de la princesa juana de austria km.                                                          42, carabanchel, Madrid, Spain
# Coordenada no encontrada para avenida de carabanchel alto - avenida de la peseta                                                  , intentando con cruce...
# Coordenada encontrada para cruce entre avenida de carabanchel alto y avenida de la peseta
# Coordenada no encontrada para calle de alcala - plaza de cibeles                                                                  , intentando con cruce...
# Coordenada encontrada para cruce entre calle de alcala y plaza de cibeles
# Coordenada encontrada para paseo del prado - plaza de canovas del castillo
# Coordenada encontrada para plaza del emperador carlos v                                                                     , 1
# Coordenada no encontrada para calle  gran via - calle de san bernardo                                                             , intentando con cruce...
# Coordenada no encontrada para cruce, intentando con 'direccion_1' y 'numero'...
# Coordenada finalmente no encontrada para calle  gran via , centro, Madrid, Spain
# Coordenada encontrada para cuesta de san vicente                                                                            , 3
# Coordenada no encontrada para calle de segovia - ronda de segovia                                                                 , intentando con cruce...
# Coordenada encontrada para cruce entre calle de segovia y ronda de segovia
# Coordenada no encontrada para calle de prim - paseo de recoletos                                                                  , intentando con cruce...
# Coordenada encontrada para cruce entre calle de prim y paseo de recoletos
# Coordenada encontrada para plaza de canovas del castillo                                                                    , 3
# Coordenada encontrada para plaza de cibeles                                                                                 , 3
# Coordenada no encontrada para plaza de cibeles - calle de alcala                                                                  , intentando con cruce...
# Coordenada encontrada para cruce entre plaza de cibeles y calle de alcala
# Coordenada no encontrada para paseo de la castellana - plaza de lima                                                              , intentando con cruce...
# Coordenada encontrada para cruce entre paseo de la castellana y plaza de lima
# Coordenada no encontrada para paseo de la castellana - plaza de cuzco                                                             , intentando con cruce...
# Coordenada encontrada para cruce entre paseo de la castellana y plaza de cuzco
# Coordenada encontrada para paseo de la castellana                                                                           , 15
# Coordenada no encontrada para paseo de la castellana - plaza de san juan de la cruz                                               , intentando con cruce...
# Coordenada encontrada para cruce entre paseo de la castellana y plaza de san juan de la cruz
# Coordenada no encontrada para calle de joaquin costa - calle de velazquez                                                         , intentando con cruce...
# Coordenada encontrada para cruce entre calle de joaquin costa y calle de velazquez
# Coordenada encontrada para paseo de la castellana                                                                           , 2
# Coordenada no encontrada para paseo de la castellana - plaza del doctor marañon                                                   , intentando con cruce...
# Coordenada encontrada para cruce entre paseo de la castellana y plaza del doctor marañon
# Coordenada no encontrada para glorieta de emilio castelar - paseo de la castellana                                                , intentando con cruce...
# Coordenada encontrada para cruce entre glorieta de emilio castelar y paseo de la castellana
# Coordenada encontrada para plaza del doctor marañon
# Coordenada encontrada para glorieta de emilio castelar
# Coordenada encontrada para paseo de la castellana                                                                           , 11
# Coordenada no encontrada para paseo de la castellana - plaza de colon                                                             , intentando con cruce...
# Coordenada encontrada para cruce entre paseo de la castellana y plaza de colon
# Coordenada encontrada para paseo de la castellana                                                                           , 1
# Coordenada encontrada para plaza de san juan de la cruz                                                                     , 1
# Coordenada no encontrada para calle de bravo murillo - calle de jose abascal                                                      , intentando con cruce...
# Coordenada encontrada para cruce entre calle de bravo murillo y calle de jose abascal
# Coordenada no encontrada para autovia  m-30 calzada 2 km.                                                                         , 1, intentando con cruce...
# Coordenada finalmente no encontrada para autovia  m-30 calzada 2 km.                                                                          1, ciudad lineal, Madrid, Spain
# Coordenada no encontrada para avenida de america km.                                                                              , 5, intentando con cruce...
# Coordenada encontrada para avenida de america km.                                                                               5, ciudad lineal, Madrid, Spain
# Coordenada no encontrada para avenida de america km.                                                                              , 45, intentando con cruce...
# Coordenada encontrada para avenida de america km.                                                                               45, ciudad lineal, Madrid, Spain
# Coordenada no encontrada para autovia  m-30 calzada 2 km.                                                                         , 2, intentando con cruce...
# Coordenada finalmente no encontrada para autovia  m-30 calzada 2 km.                                                                          2, ciudad lineal, Madrid, Spain
# Coordenada no encontrada para autovia  m-30 calzada 2 km.                                                                         , 32, intentando con cruce...
# Coordenada finalmente no encontrada para autovia  m-30 calzada 2 km.                                                                          32, fuencarral-el pardo, Madrid, Spain
# Coordenada no encontrada para autovia  m-30 calzada 1 km.                                                                         , 32, intentando con cruce...
# Coordenada finalmente no encontrada para autovia  m-30 calzada 1 km.                                                                          32, fuencarral-el pardo, Madrid, Spain
# Coordenada no encontrada para autovia  m-30 calzada 1 km.                                                                         , 31, intentando con cruce...
# Coordenada finalmente no encontrada para autovia  m-30 calzada 1 km.                                                                          31, fuencarral-el pardo, Madrid, Spain
# Coordenada no encontrada para autovia  m-30 calzada 1 km.                                                                         , 38, intentando con cruce...
# Coordenada finalmente no encontrada para autovia  m-30 calzada 1 km.                                                                          38, fuencarral-el pardo, Madrid, Spain
# Coordenada encontrada para paseo de la castellana                                                                           , 259
# Coordenada no encontrada para autovia  m-30 calzada 1 km.                                                                         , 315, intentando con cruce...
# Coordenada finalmente no encontrada para autovia  m-30 calzada 1 km.                                                                          315, fuencarral-el pardo, Madrid, Spain
# Coordenada no encontrada para autovia  m-30 calzada 1 km.                                                                         , 317, intentando con cruce...
# Coordenada finalmente no encontrada para autovia  m-30 calzada 1 km.                                                                          317, fuencarral-el pardo, Madrid, Spain
# Coordenada encontrada para glorieta del rio urubamba
# Coordenada no encontrada para calle de ariadna                                                                                    , intentando con cruce...
# Coordenada finalmente no encontrada para calle de ariadna                                                                                     , hortaleza, Madrid, Spain
# Coordenada no encontrada para avenida de niceto alcala zamora - avenida del alcalde conde de mayalde                              , intentando con cruce...
# Coordenada encontrada para cruce entre avenida de niceto alcala zamora y avenida del alcalde conde de mayalde
# Coordenada encontrada para calle de manuel azaña
# Coordenada encontrada para avenida de niceto alcala zamora                                                                  , 3
# Coordenada no encontrada para calle del aconcagua - glorieta del rio urubamba                                                     , intentando con cruce...
# Coordenada no encontrada para cruce, intentando con 'direccion_1' y 'numero'...
# Coordenada finalmente no encontrada para calle del aconcagua , hortaleza, Madrid, Spain
# Coordenada no encontrada para calle de los emigrantes - glorieta del mar de cristal                                               , intentando con cruce...
# Coordenada no encontrada para cruce, intentando con 'direccion_1' y 'numero'...
# Coordenada finalmente no encontrada para calle de los emigrantes , hortaleza, Madrid, Spain
# Coordenada no encontrada para avenida de machupichu - calle de silvano                                                            , intentando con cruce...
# Coordenada encontrada para cruce entre avenida de machupichu y calle de silvano
# Coordenada no encontrada para avenida de francisco pi y margall - avenida de niceto alcala zamora                                 , intentando con cruce...
# Coordenada encontrada para cruce entre avenida de francisco pi y margall y avenida de niceto alcala zamora
# Coordenada no encontrada para autovia  m-40 - calle de silvano                                                                    , intentando con cruce...
# Coordenada no encontrada para cruce, intentando con 'direccion_1' y 'numero'...
# Coordenada finalmente no encontrada para autovia  m-40 , hortaleza, Madrid, Spain
# Coordenada no encontrada para avenida de niceto alcala zamora - calle de ana de austria                                           , intentando con cruce...
# Coordenada encontrada para cruce entre avenida de niceto alcala zamora y calle de ana de austria
# Coordenada no encontrada para calle de arturo soria - calle de manuel azaña                                                       , intentando con cruce...
# Coordenada encontrada para cruce entre calle de arturo soria y calle de manuel azaña
# Coordenada no encontrada para calle del aconcagua                                                                              , 2, intentando con cruce...
# Coordenada finalmente no encontrada para calle del aconcagua                                                                               2, hortaleza, Madrid, Spain
# Coordenada encontrada para carretera a la estacion de hortaleza                                                             , 58
# Coordenada no encontrada para calle del aconcagua - calle del nevado del cumbal                                                   , intentando con cruce...
# Coordenada no encontrada para cruce, intentando con 'direccion_1' y 'numero'...
# Coordenada finalmente no encontrada para calle del aconcagua , hortaleza, Madrid, Spain
# Coordenada no encontrada para calle de alcorisa - calle de silvano                                                                , intentando con cruce...
# Coordenada encontrada para cruce entre calle de alcorisa y calle de silvano
# Coordenada encontrada para gran via de hortaleza                                                                            , 5
# Coordenada no encontrada para glorieta de yucatan                                                                                 , intentando con cruce...
# Coordenada finalmente no encontrada para glorieta de yucatan                                                                                  , hortaleza, Madrid, Spain
# Coordenada no encontrada para avenida de machupichu - plaza de manuel rodrigo                                                     , intentando con cruce...
# Coordenada encontrada para cruce entre avenida de machupichu y plaza de manuel rodrigo
# Coordenada no encontrada para avenida de niceto alcala zamora - avenida de francisco pi y margall                                 , intentando con cruce...
# Coordenada encontrada para cruce entre avenida de niceto alcala zamora y avenida de francisco pi y margall
# Coordenada no encontrada para avenida de los poblados - avenida del general fanjul                                                , intentando con cruce...
# Coordenada encontrada para cruce entre avenida de los poblados y avenida del general fanjul
# Coordenada no encontrada para calle  via carpetana - paseo de la ermita del santo                                                 , intentando con cruce...
# Coordenada encontrada para cruce entre calle  via carpetana y paseo de la ermita del santo
# Coordenada no encontrada para calle de los yebenes - calle de valmojado                                                           , intentando con cruce...
# Coordenada encontrada para cruce entre calle de los yebenes y calle de valmojado
# Coordenada no encontrada para paseo de extremadura km.                                                                            , 5, intentando con cruce...
# Coordenada encontrada para paseo de extremadura km.                                                                             5, latina, Madrid, Spain
# Coordenada no encontrada para calle de camarena - calle de illescas                                                               , intentando con cruce...
# Coordenada encontrada para cruce entre calle de camarena y calle de illescas
# Coordenada encontrada para avenida del general fanjul                                                                       , 2
# Coordenada no encontrada para calle de la alhambra - calle del concejal francisco jose jimenez martin                             , intentando con cruce...
# Coordenada encontrada para cruce entre calle de la alhambra y calle del concejal francisco jose jimenez martin
# Coordenada no encontrada para paseo de extremadura km.                                                                            , 7, intentando con cruce...
# Coordenada encontrada para paseo de extremadura km.                                                                             7, latina, Madrid, Spain
# Coordenada no encontrada para paseo de extremadura km.                                                                            , 4, intentando con cruce...
# Coordenada encontrada para paseo de extremadura km.                                                                             4, latina, Madrid, Spain
# Coordenada encontrada para glorieta del puente de segovia                                                                   , 1
# Coordenada no encontrada para paseo de extremadura km.                                                                            , 57, intentando con cruce...
# Coordenada encontrada para paseo de extremadura km.                                                                             57, latina, Madrid, Spain
# Coordenada no encontrada para avenida de los poblados - avenida del padre piquer                                                  , intentando con cruce...
# Coordenada encontrada para cruce entre avenida de los poblados y avenida del padre piquer
# Coordenada no encontrada para avenida de la aviacion - paseo de extremadura                                                       , intentando con cruce...
# Coordenada encontrada para cruce entre avenida de la aviacion y paseo de extremadura
# Coordenada no encontrada para calle de cuart de poblet - calle de la alhambra                                                     , intentando con cruce...
# Coordenada encontrada para cruce entre calle de cuart de poblet y calle de la alhambra
# Coordenada encontrada para carretera del barrio de la fortuna                                                               , 1
# Coordenada encontrada para carretera del barrio de la fortuna                                                               , 21
# Coordenada encontrada para avenida de portugal                                                                              , 1
# Coordenada no encontrada para calle de la danza - calle de la sinfonia                                                            , intentando con cruce...
# Coordenada encontrada para cruce entre calle de la danza y calle de la sinfonia
# Coordenada no encontrada para paseo de extremadura - calle de guadarrama                                                          , intentando con cruce...
# Coordenada encontrada para cruce entre paseo de extremadura y calle de guadarrama
# Coordenada no encontrada para avenida de la aviacion - calle de monroy                                                            , intentando con cruce...
# Coordenada encontrada para cruce entre avenida de la aviacion y calle de monroy
# Coordenada encontrada para avenida de los poblados                                                                          , 7
# Coordenada no encontrada para autovia  m-30 calzada 1 km.                                                                         , 23, intentando con cruce...
# Coordenada finalmente no encontrada para autovia  m-30 calzada 1 km.                                                                          23, moncloa-aravaca, Madrid, Spain
# Coordenada no encontrada para avenida de la reina victoria - avenida de pablo iglesias                                            , intentando con cruce...
# Coordenada encontrada para cruce entre avenida de la reina victoria y avenida de pablo iglesias
# Coordenada encontrada para avenida del padre huidobro                                                                       , 5
# Coordenada encontrada para glorieta de san vicente                                                                          , 1
# Coordenada encontrada para avenida del arco de la victoria                                                                  , 1
# Coordenada no encontrada para autovia  m-30 calzada 2 km.                                                                         , 23, intentando con cruce...
# Coordenada finalmente no encontrada para autovia  m-30 calzada 2 km.                                                                          23, moncloa-aravaca, Madrid, Spain
# Coordenada no encontrada para autovia  m-30 calzada 1 km.                                                                         , 19, intentando con cruce...
# Coordenada finalmente no encontrada para autovia  m-30 calzada 1 km.                                                                          19, moncloa-aravaca, Madrid, Spain
# Coordenada encontrada para paseo de ruperto chapi
# Coordenada no encontrada para calle  gran via - plaza de españa                                                                   , intentando con cruce...
# Coordenada no encontrada para cruce, intentando con 'direccion_1' y 'numero'...
# Coordenada finalmente no encontrada para calle  gran via , moncloa-aravaca, Madrid, Spain
# Coordenada encontrada para calle de sinesio delgado                                                                         , 8
# Coordenada no encontrada para avenida de seneca - calle de martin fierro                                                          , intentando con cruce...
# Coordenada no encontrada para cruce, intentando con 'direccion_1' y 'numero'...
# Coordenada encontrada para avenida de seneca , moncloa-aravaca, Madrid, Spain
# Coordenada no encontrada para avenida del mediterraneo km.                                                                        , 4, intentando con cruce...
# Coordenada encontrada para avenida del mediterraneo km.                                                                         4, moratalaz, Madrid, Spain
# Coordenada no encontrada para avenida del mediterraneo km.                                                                        , 5, intentando con cruce...
# Coordenada encontrada para avenida del mediterraneo km.                                                                         5, moratalaz, Madrid, Spain
# Coordenada no encontrada para avenida del mediterraneo km.                                                                        , 6, intentando con cruce...
# Coordenada encontrada para avenida del mediterraneo km.                                                                         6, moratalaz, Madrid, Spain
# Coordenada no encontrada para calle de la fuente carrantona - calle de la hacienda de pavones                                     , intentando con cruce...
# Coordenada encontrada para cruce entre calle de la fuente carrantona y calle de la hacienda de pavones
# Coordenada no encontrada para autovia  m-30 calzada 2 km.                                                                         , 9, intentando con cruce...
# Coordenada finalmente no encontrada para autovia  m-30 calzada 2 km.                                                                          9, moratalaz, Madrid, Spain
# Coordenada no encontrada para avenida del doctor garcia tapia - calle de la fuente carrantona                                     , intentando con cruce...
# Coordenada encontrada para cruce entre avenida del doctor garcia tapia y calle de la fuente carrantona
# Coordenada no encontrada para autovia  m-23 salida - calle de la fuente carrantona                                                , intentando con cruce...
# Coordenada no encontrada para cruce, intentando con 'direccion_1' y 'numero'...
# Coordenada finalmente no encontrada para autovia  m-23 salida , moratalaz, Madrid, Spain
# Coordenada no encontrada para calle de la fuente carrantona - calle de luis de hoyos sainz                                        , intentando con cruce...
# Coordenada encontrada para cruce entre calle de la fuente carrantona y calle de luis de hoyos sainz
# Coordenada no encontrada para avenida del doctor garcia tapia - calle  arroyo de la media legua                                   , intentando con cruce...
# Coordenada no encontrada para cruce, intentando con 'direccion_1' y 'numero'...
# Coordenada encontrada para avenida del doctor garcia tapia , moratalaz, Madrid, Spain
# Coordenada no encontrada para calle de la fuente carrantona - autovia  m-23 salida                                                , intentando con cruce...
# Coordenada no encontrada para cruce, intentando con 'direccion_1' y 'numero'...
# Coordenada encontrada para calle de la fuente carrantona , moratalaz, Madrid, Spain
# Coordenada no encontrada para avenida de la albufera - avenida de pablo neruda                                                    , intentando con cruce...
# Coordenada encontrada para cruce entre avenida de la albufera y avenida de pablo neruda
# Coordenada no encontrada para avenida de la albufera - avenida de rafael alberti                                                  , intentando con cruce...
# Coordenada encontrada para cruce entre avenida de la albufera y avenida de rafael alberti
# Coordenada no encontrada para autovia  m-30 calzada 2 km.                                                                         , 12, intentando con cruce...
# Coordenada finalmente no encontrada para autovia  m-30 calzada 2 km.                                                                          12, puente de vallecas, Madrid, Spain
# Coordenada no encontrada para autovia  m-30 calzada 2 km.                                                                         , 15, intentando con cruce...
# Coordenada finalmente no encontrada para autovia  m-30 calzada 2 km.                                                                          15, puente de vallecas, Madrid, Spain
# Coordenada no encontrada para autovia  m-30 calzada 2 km.                                                                         , 11, intentando con cruce...
# Coordenada finalmente no encontrada para autovia  m-30 calzada 2 km.                                                                          11, puente de vallecas, Madrid, Spain
# Coordenada encontrada para avenida de entrevias                                                                             , 2
# Coordenada no encontrada para autovia  m-30 calzada 2 km.                                                                         , 16, intentando con cruce...
# Coordenada finalmente no encontrada para autovia  m-30 calzada 2 km.                                                                          16, puente de vallecas, Madrid, Spain
# Coordenada no encontrada para avenida del mediterraneo km.                                                                        , 67, intentando con cruce...
# Coordenada encontrada para avenida del mediterraneo km.                                                                         67, puente de vallecas, Madrid, Spain
# Coordenada no encontrada para calle de alfonso xii - paseo de la infanta isabel                                                   , intentando con cruce...
# Coordenada encontrada para cruce entre calle de alfonso xii y paseo de la infanta isabel
# Coordenada no encontrada para autovia  m-30 calzada 1 km.                                                                         , 9, intentando con cruce...
# Coordenada finalmente no encontrada para autovia  m-30 calzada 1 km.                                                                          9, retiro, Madrid, Spain
# Coordenada no encontrada para paseo del prado - plaza de cibeles                                                                  , intentando con cruce...
# Coordenada encontrada para cruce entre paseo del prado y plaza de cibeles
# Coordenada no encontrada para autovia  m-30 calzada 1 km.                                                                         , 16, intentando con cruce...
# Coordenada finalmente no encontrada para autovia  m-30 calzada 1 km.                                                                          16, retiro, Madrid, Spain
# Coordenada no encontrada para autovia  m-30 calzada 1 km.                                                                         , 15, intentando con cruce...
# Coordenada finalmente no encontrada para autovia  m-30 calzada 1 km.                                                                          15, retiro, Madrid, Spain
# Coordenada encontrada para plaza de cibeles                                                                                 , 1
# Coordenada encontrada para paseo del prado                                                                                  , 1
# Coordenada no encontrada para autovia  m-30 calzada 1 km.                                                                         , 83, intentando con cruce...
# Coordenada finalmente no encontrada para autovia  m-30 calzada 1 km.                                                                          83, retiro, Madrid, Spain
# Coordenada encontrada para avenida del mediterraneo                                                                         , 32
# Coordenada encontrada para plaza de canovas del castillo                                                                    , 2
# Coordenada no encontrada para calle de maria de molina - calle de velazquez                                                       , intentando con cruce...
# Coordenada encontrada para cruce entre calle de maria de molina y calle de velazquez
# Coordenada encontrada para avenida de america - calle de cartagena
# Coordenada no encontrada para calle de o'donnell - calle del doctor esquerdo                                                      , intentando con cruce...
# Coordenada encontrada para cruce entre calle de o'donnell y calle del doctor esquerdo
# Coordenada encontrada para plaza de colon                                                                                   , 4
# Coordenada no encontrada para calle de goya - calle de velazquez                                                                  , intentando con cruce...
# Coordenada encontrada para cruce entre calle de goya y calle de velazquez
# Coordenada no encontrada para autovia  m-40 - avenida de arcentales                                                               , intentando con cruce...
# Coordenada encontrada para cruce entre autovia  m-40 y avenida de arcentales
# Coordenada no encontrada para avenida de arcentales - plaza de grecia                                                             , intentando con cruce...
# Coordenada encontrada para cruce entre avenida de arcentales y plaza de grecia
# Coordenada no encontrada para avenida de arcentales - autovia  m-40                                                               , intentando con cruce...
# Coordenada encontrada para cruce entre avenida de arcentales y autovia  m-40
# Coordenada no encontrada para avenida de arcentales - avenida de canillejas a vicalvaro                                           , intentando con cruce...
# Coordenada encontrada para cruce entre avenida de arcentales y avenida de canillejas a vicalvaro
# Coordenada no encontrada para avenida de canillejas a vicalvaro - autovia  m-40                                                   , intentando con cruce...
# Coordenada encontrada para cruce entre avenida de canillejas a vicalvaro y autovia  m-40
# Coordenada encontrada para avenida de arcentales                                                                            , 7
# Coordenada no encontrada para calle de alcala - calle de san romualdo                                                             , intentando con cruce...
# Coordenada encontrada para cruce entre calle de alcala y calle de san romualdo
# Coordenada encontrada para avenida de arcentales                                                                            , 26
# Coordenada no encontrada para calle de alcala - calle de gutierrez canales                                                        , intentando con cruce...
# Coordenada encontrada para cruce entre calle de alcala y calle de gutierrez canales
# Coordenada no encontrada para calle de julian camarillo - calle de san romualdo                                                   , intentando con cruce...
# Coordenada encontrada para cruce entre calle de julian camarillo y calle de san romualdo
# Coordenada no encontrada para calle de raimundo fernandez villaverde - paseo de la castellana                                     , intentando con cruce...
# Coordenada encontrada para cruce entre calle de raimundo fernandez villaverde y paseo de la castellana
# Coordenada no encontrada para calle de orense - calle de raimundo fernandez villaverde                                            , intentando con cruce...
# Coordenada encontrada para cruce entre calle de orense y calle de raimundo fernandez villaverde
# Coordenada encontrada para paseo de la castellana                                                                           , 141
# Coordenada no encontrada para autovia  m-40 - avenida de andalucia                                                                , intentando con cruce...
# Coordenada no encontrada para cruce, intentando con 'direccion_1' y 'numero'...
# Coordenada finalmente no encontrada para autovia  m-40 , usera, Madrid, Spain
# Coordenada no encontrada para avenida de andalucia - avenida de los poblados                                                      , intentando con cruce...
# Coordenada encontrada para cruce entre avenida de andalucia y avenida de los poblados
# Coordenada no encontrada para avenida de andalucia - avenida de los rosales                                                       , intentando con cruce...
# Coordenada encontrada para cruce entre avenida de andalucia y avenida de los rosales
# Coordenada encontrada para glorieta de cadiz
# Coordenada no encontrada para avenida de andalucia - autovia  m-40                                                                , intentando con cruce...
# Coordenada no encontrada para cruce, intentando con 'direccion_1' y 'numero'...
# Coordenada encontrada para avenida de andalucia , usera, Madrid, Spain
# Coordenada encontrada para avenida de andalucia                                                                             , 19
# Coordenada encontrada para avenida de los poblados - avenida de rafaela ybarra
# Coordenada encontrada para avenida de andalucia                                                                             , 32
# Coordenada encontrada para camino  viejo de vicalvaro                                                                       , 7
# Coordenada no encontrada para avenida del mediterraneo km.                                                                        , 7, intentando con cruce...
# Coordenada encontrada para avenida del mediterraneo km.                                                                         7, vicalvaro, Madrid, Spain
# Coordenada no encontrada para avenida de daroca - calle de casalarreina                                                           , intentando con cruce...
# Coordenada encontrada para cruce entre avenida de daroca y calle de casalarreina
# Coordenada no encontrada para avenida de la democracia - bulevar de jose prat                                                     , intentando con cruce...
# Coordenada encontrada para cruce entre avenida de la democracia y bulevar de jose prat
# Coordenada encontrada para avenida de la democracia                                                                         , 23
# Coordenada no encontrada para calle de minerva - calle de san cipriano                                                            , intentando con cruce...
# Coordenada encontrada para cruce entre calle de minerva y calle de san cipriano
# Coordenada no encontrada para bulevar de indalecio prieto - calle de los juglares                                                 , intentando con cruce...
# Coordenada encontrada para cruce entre bulevar de indalecio prieto y calle de los juglares
# Coordenada encontrada para carretera de vicalvaro a la estacion de o'donnell                                                , 2
# Coordenada no encontrada para carretera de canillejas                                                                             , intentando con cruce...
# Coordenada finalmente no encontrada para carretera de canillejas                                                                              , vicalvaro, Madrid, Spain
# Coordenada no encontrada para carretera de vicalvaro a coslada km.                                                                , 35, intentando con cruce...
# Coordenada encontrada para carretera de vicalvaro a coslada km.                                                                 35, vicalvaro, Madrid, Spain
# Coordenada no encontrada para avenida de la gran via del este - calle de san cipriano                                             , intentando con cruce...
# Coordenada encontrada para cruce entre avenida de la gran via del este y calle de san cipriano
# Coordenada no encontrada para calle de villablanca - calle del jardin de la duquesa                                               , intentando con cruce...
# Coordenada no encontrada para cruce, intentando con 'direccion_1' y 'numero'...
# ...
# Coordenada encontrada para avenida de daroca - calle de calahorra
# Coordenada encontrada para plaza de alosno                                                                                  , 4
# Coordenada no encontrada para calle de minerva - calle del molino viejo                                                           , intentando con cruce...
# Coordenada encontrada para cruce entre calle de minerva y calle del molino viejo
# Coordenada no encontrada para avenida de buenos aires - avenida de pablo neruda                                                   , intentando con cruce...
# Coordenada no encontrada para cruce, intentando con 'direccion_1' y 'numero'...
# Coordenada finalmente no encontrada para avenida de buenos aires , villa de vallecas, Madrid, Spain
# Coordenada no encontrada para avenida de la gavia - avenida del mayorazgo                                                         , intentando con cruce...
# Coordenada encontrada para cruce entre avenida de la gavia y avenida del mayorazgo
# Coordenada no encontrada para avenida del cerro milano - calle del alto de la sartenilla                                          , intentando con cruce...
# Coordenada encontrada para cruce entre avenida del cerro milano y calle del alto de la sartenilla
# Coordenada encontrada para cañada  real galiana                                                                             , 5
# Coordenada encontrada para avenida de la gran via del este                                                                  , 8
# Coordenada encontrada para calle del alto del retiro                                                                        , 33
# Coordenada encontrada para calle de domingo parraga                                                                         , 84
# Coordenada no encontrada para autovia  m-40 - avenida de los rosales                                                              , intentando con cruce...
# Coordenada no encontrada para cruce, intentando con 'direccion_1' y 'numero'...
# Coordenada finalmente no encontrada para autovia  m-40 , villaverde, Madrid, Spain
# Coordenada no encontrada para avenida de andalucia km.                                                                            , 9, intentando con cruce...
# Coordenada encontrada para avenida de andalucia km.                                                                             9, villaverde, Madrid, Spain
# Coordenada encontrada para avenida de andalucia                                                                             , 9
# Coordenada no encontrada para avenida de los rosales km.                                                                          , 22, intentando con cruce...
# Coordenada encontrada para avenida de los rosales km.                                                                           22, villaverde, Madrid, Spain
# Coordenada encontrada para avenida de america                                                                               , 115
# Coordenada no encontrada para calle  via lusitana - calle del aguacate                                                            , intentando con cruce...
# Coordenada encontrada para cruce entre calle  via lusitana y calle del aguacate
# Coordenada no encontrada para avenida de los poblados - calle de carabanchel bajo                                                 , intentando con cruce...
# Coordenada encontrada para cruce entre avenida de los poblados y calle de carabanchel bajo
# Coordenada encontrada para calle de tomas redondo                                                                           , 2
# Coordenada no encontrada para paseo de extremadura km.                                                                            , 36, intentando con cruce...
# Coordenada encontrada para paseo de extremadura km.                                                                             36, latina, Madrid, Spain
# Coordenada no encontrada para autovia  m-30 calzada 2 km.                                                                         , 18, intentando con cruce...
# Coordenada finalmente no encontrada para autovia  m-30 calzada 2 km.                                                                          18, latina, Madrid, Spain
# Coordenada no encontrada para calle de francisco silvela - calle del principe de vergara                                          , intentando con cruce...
# Coordenada encontrada para cruce entre calle de francisco silvela y calle del principe de vergara
# Coordenada no encontrada para autovia  m-40 - avenida de canillejas a vicalvaro                                                   , intentando con cruce...
# Coordenada encontrada para cruce entre autovia  m-40 y avenida de canillejas a vicalvaro
# Coordenada encontrada para plaza de lima
# Coordenada no encontrada para paseo de la castellana - calle de raimundo fernandez villaverde                                     , intentando con cruce...
# Coordenada encontrada para cruce entre paseo de la castellana y calle de raimundo fernandez villaverde
# Coordenada no encontrada para calle de bravo murillo - calle del general yagüe                                                    , intentando con cruce...
# Coordenada encontrada para cruce entre calle de bravo murillo y calle del general yagüe
# Coordenada no encontrada para autovia  m-40 - avenida del doctor garcia tapia                                                     , intentando con cruce...
# Coordenada no encontrada para cruce, intentando con 'direccion_1' y 'numero'...
# Coordenada finalmente no encontrada para autovia  m-40 , vicalvaro, Madrid, Spain
# Coordenada no encontrada para avenida de la democracia - avenida de las comunidades                                               , intentando con cruce...
# Coordenada encontrada para cruce entre avenida de la democracia y avenida de las comunidades
# Coordenada no encontrada para avenida de la democracia - avenida del mediterraneo                                                 , intentando con cruce...
# Coordenada encontrada para cruce entre avenida de la democracia y avenida del mediterraneo
# Coordenada encontrada para avenida del mayorazgo                                                                            , 2
# Coordenada encontrada para avenida de america                                                                               , 119
# Coordenada no encontrada para calle de guadarrama - paseo de extremadura                                                          , intentando con cruce...
# Coordenada encontrada para cruce entre calle de guadarrama y paseo de extremadura
# Coordenada no encontrada para avenida de la gavia - avenida del cerro milano                                                      , intentando con cruce...
# Coordenada encontrada para cruce entre avenida de la gavia y avenida del cerro milano
# Coordenada no encontrada para avenida del ensanche de vallecas                                                                 , 2, intentando con cruce...
# Coordenada finalmente no encontrada para avenida del ensanche de vallecas                                                                  2, villa de vallecas, Madrid, Spain
# Coordenada encontrada para avenida del mayorazgo                                                                            , 79
# Coordenada no encontrada para avenida  sur del aeropuerto de barajas - avenida de la hispanidad                                   , intentando con cruce...
# Coordenada encontrada para cruce entre avenida  sur del aeropuerto de barajas y avenida de la hispanidad
# Coordenada no encontrada para autovia  m-45 - avenida del mayorazgo                                                               , intentando con cruce...
# Coordenada encontrada para cruce entre autovia  m-45 y avenida del mayorazgo
# Coordenada no encontrada para autovia  m-45 - avenida del ensanche de vallecas                                                    , intentando con cruce...
# Coordenada no encontrada para cruce, intentando con 'direccion_1' y 'numero'...
# Coordenada encontrada para autovia  m-45 , villa de vallecas, Madrid, Spain
# Coordenada encontrada para avenida  sur del aeropuerto de barajas                                                           , 4
# Coordenada encontrada para avenida del partenon                                                                             , 1
# Coordenada no encontrada para avenida de america salida km.                                                                       , 4, intentando con cruce...
# Coordenada finalmente no encontrada para avenida de america salida km.                                                                        4, ciudad lineal, Madrid, Spain
# Coordenada no encontrada para avenida de america entrada km.                                                                      , 4, intentando con cruce...
# Coordenada finalmente no encontrada para avenida de america entrada km.                                                                       4, ciudad lineal, Madrid, Spain
# Coordenada no encontrada para autovia  m-30 calzada 2 km.                                                                         , intentando con cruce...
# Coordenada finalmente no encontrada para autovia  m-30 calzada 2 km.                                                                          , ciudad lineal, Madrid, Spain
# Coordenada no encontrada para calle de arturo soria - cuesta del sagrado corazon                                                  , intentando con cruce...
# Coordenada no encontrada para cruce, intentando con 'direccion_1' y 'numero'...
# Coordenada encontrada para calle de arturo soria , hortaleza, Madrid, Spain
# Coordenada no encontrada para calle de alcala - calle de los hermanos garcia noblejas                                             , intentando con cruce...
# Coordenada encontrada para cruce entre calle de alcala y calle de los hermanos garcia noblejas
# Coordenada no encontrada para avenida de la albufera - avenida de la democracia                                                   , intentando con cruce...
# Coordenada encontrada para cruce entre avenida de la albufera y avenida de la democracia
# Coordenada no encontrada para carretera del vertedero municipal valdemingomez                                                  , 4, intentando con cruce...
# Coordenada finalmente no encontrada para carretera del vertedero municipal valdemingomez                                                   4, villa de vallecas, Madrid, Spain
# Coordenada no encontrada para autovia  m-30 calzada 1 km.                                                                         , 314, intentando con cruce...
# Coordenada finalmente no encontrada para autovia  m-30 calzada 1 km.                                                                          314, fuencarral-el pardo, Madrid, Spain
# Coordenada no encontrada para calle de cea bermudez - calle de vallehermoso                                                       , intentando con cruce...
# Coordenada no encontrada para cruce, intentando con 'direccion_1' y 'numero'...
# Coordenada encontrada para calle de cea bermudez , moncloa-aravaca, Madrid, Spain
# Coordenada encontrada para avenida de los reyes catolicos                                                                   , 1
# Coordenada encontrada para cuesta de san vicente                                                                            , 4
# Coordenada no encontrada para cuesta de san vicente - plaza de españa                                                             , intentando con cruce...
# Coordenada encontrada para cruce entre cuesta de san vicente y plaza de españa
# Coordenada no encontrada para calle de ferraz - calle del marques de urquijo                                                      , intentando con cruce...
# Coordenada encontrada para cruce entre calle de ferraz y calle del marques de urquijo
# Coordenada no encontrada para calle de diego de leon - calle de velazquez                                                         , intentando con cruce...
# Coordenada encontrada para cruce entre calle de diego de leon y calle de velazquez
# Coordenada no encontrada para calle de julian camarillo - calle de los hermanos garcia noblejas                                   , intentando con cruce...
# Coordenada no encontrada para cruce, intentando con 'direccion_1' y 'numero'...
# Coordenada finalmente no encontrada para calle de julian camarillo , vicalvaro, Madrid, Spain
# Coordenada encontrada para avenida de abrantes - avenida de los poblados
# Coordenada no encontrada para carretera de colmenar viejo km.                                                                     , 91, intentando con cruce...
# Coordenada encontrada para carretera de colmenar viejo km.                                                                      91, fuencarral-el pardo, Madrid, Spain
# Coordenada no encontrada para autovia  m-30 calzada 2 km.                                                                         , 3, intentando con cruce...
# Coordenada finalmente no encontrada para autovia  m-30 calzada 2 km.                                                                          3, fuencarral-el pardo, Madrid, Spain
# Coordenada no encontrada para avenida de alberto alcocer - calle del doctor fleming                                               , intentando con cruce...
# Coordenada no encontrada para cruce, intentando con 'direccion_1' y 'numero'...
# Coordenada finalmente no encontrada para avenida de alberto alcocer , hortaleza, Madrid, Spain
# Coordenada no encontrada para autovia  m-40 - calle del aconcagua                                                                 , intentando con cruce...
# Coordenada no encontrada para cruce, intentando con 'direccion_1' y 'numero'...
# Coordenada finalmente no encontrada para autovia  m-40 , hortaleza, Madrid, Spain
# Coordenada no encontrada para paseo de la ermita del santo - paseo del quince de mayo                                             , intentando con cruce...
# Coordenada no encontrada para cruce, intentando con 'direccion_1' y 'numero'...
# Coordenada encontrada para paseo de la ermita del santo , latina, Madrid, Spain
# Coordenada no encontrada para autovia  m-45 - avenida  real de pinto                                                              , intentando con cruce...
# Coordenada encontrada para cruce entre autovia  m-45 y avenida  real de pinto
# Coordenada no encontrada para autov. m-30 +03200e, +32e, intentando con cruce...
# Coordenada finalmente no encontrada para autov. m-30 +03200e +32e, fuencarral-el pardo, Madrid, Spain
# Coordenada encontrada para calle moreno nieto , 16

# %%
print(df_unicas[df_unicas.duplicated('localizacion_completa', keep=False)])
# Out:
# Empty DataFrame
# Columns: [localizacion_completa, distrito, direccion_1, direccion_2, numero, coordenada_x, coordenada_y]
# Index: []

# %%
print(len(df_resultado_final))
# Out:
# 10462

# %% [markdown]
# **Aquí lo que vamos a hacer es llevar los datos de df_unicas al df_resultado_final todas las coordenadas que ha encontrado**

# %%
#Cargamos el pickle si no has ejecutado
#df_unicas = pd.read_pickle('mapas/df_coordenadas.pkl')

# Crea un índice temporal en df_resultado_final basado en 'localizacion_completa'
df_resultado_final.set_index('localizacion_completa', inplace=True)

# Crea un índice temporal en df_unicas basado en 'localizacion_completa'
df_unicas.set_index('localizacion_completa', inplace=True)

# Actualiza 'coordenada_x' y 'coordenada_y' en df_resultado_final con los valores de df_unicas
df_resultado_final.update(df_unicas[['coordenada_x', 'coordenada_y']])

# Resetea el índice para volver al estado anterior
df_resultado_final.reset_index(inplace=True)
df_unicas.reset_index(inplace=True)

# %% [markdown]
# **Volvemos a comprobar cuantas coordenadas no ha encontrado**

# %%
nan_coordenada_x = df_resultado_final['coordenada_x'].isna().sum()
nan_coordenada_y = df_resultado_final['coordenada_y'].isna().sum()

print(f"Número de valores NaN en 'coordenada_x': {nan_coordenada_x}")
print(f"Número de valores NaN en 'coordenada_y': {nan_coordenada_y}")
# Out:
# Número de valores NaN en 'coordenada_x': 5441
# Número de valores NaN en 'coordenada_y': 5441

# %% [markdown]
# **Aquí vamos a quitar las coordenadas que no ha encontrado y pasamos de UTM a latitud y longitud,
# coordenadas que necesita folium**

# %%
# Filtrar filas donde 'coordenada_x' o 'coordenada_y' son NaN
df_coordenadas = df_resultado_final.dropna(subset=['coordenada_x', 'coordenada_y'])

# Definir el sistema de proyección UTM y WGS84, esto es para lo de UTM... que así venían los datos del ayto de Madrid ;)
utm_proj = Proj(proj='utm', zone=30, ellps='WGS84', preserve_units=False)
wgs84_proj = Proj(proj='latlong', datum='WGS84')

# Aquí convertimos de UTM a latitud y longitud
def utm_to_latlon(row):
    lon, lat = transform(utm_proj, wgs84_proj, row['coordenada_x'], row['coordenada_y'])
    return pd.Series({'latitud': lat, 'longitud': lon})

df_coordenadas[['latitud', 'longitud']] = df_coordenadas.apply(utm_to_latlon, axis=1)

df_coordenadas
# Out:
# C:\Users\34670\AppData\Local\Temp\ipykernel_18092\86459913.py:10: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lon, lat = transform(utm_proj, wgs84_proj, row['coordenada_x'], row['coordenada_y'])
# C:\Users\34670\AppData\Local\Temp\ipykernel_18092\86459913.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_coordenadas[['latitud', 'longitud']] = df_coordenadas.apply(utm_to_latlon, axis=1)
# C:\Users\34670\AppData\Local\Temp\ipykernel_18092\86459913.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_coordenadas[['latitud', 'longitud']] = df_coordenadas.apply(utm_to_latlon, axis=1)
#                                    localizacion_completa  accidente_id  \
# 20     calle de segovia - paseo de la virgen del puer...   2010.435000
# 24     avenida del planetario - calle de mendez alvar...   2010.562400
# 26     avenida de la ciudad de barcelona             ...   2010.100680
# 29     paseo de santa maria de la cabeza             ...   2010.144500
# 41     glorieta de la ermita de la virgen de la soled...   2010.894400
# ...                                                  ...           ...
# 10457                            plaza. gabriel miro , 7   2024.001546
# 10458                         calle nuñez de balboa , 86   2024.001547
# 10459                      calle vigil - calle boyer, 2a   2024.001548
# 10460                             autov. m-30 09nc, 9nc7   2024.001550
# 10461           calle doctor esquerdo - calle moneda, 66   2024.001555
#
#            fecha  rango_horario  \
# 20    2010-01-16              1
# 24    2010-06-21             14
# 26    2010-11-11             20
# 29    2010-01-22              6
# 41    2010-10-11             18
# ...          ...            ...
# 10457 2024-01-15             17
# 10458 2024-01-15             20
# 10459 2024-01-15             19
# 10460 2024-01-15             20
# 10461 2024-01-15             21
#
#                                             localizacion numero    distrito  \
# 20     calle de segovia - paseo de la virgen del puer...         arganzuela
# 24     avenida del planetario - calle de mendez alvar...         arganzuela
# 26     avenida de la ciudad de barcelona             ...      2  arganzuela
# 29     paseo de santa maria de la cabeza             ...      1  arganzuela
# 41     glorieta de la ermita de la virgen de la soled...            barajas
# ...                                                  ...    ...         ...
# 10457                               plaza. gabriel miro       7      centro
# 10458                             calle nuñez de balboa      86   salamanca
# 10459                          calle vigil - calle boyer     2a   vicalvaro
# 10460                                   autov. m-30 09nc   9nc7      retiro
# 10461               calle doctor esquerdo - calle moneda     66      retiro
#
#         coordenada_x  coordenada_y     condicion  ... victimas  \
# 20     438928.763526  4.473716e+06     favorable  ...      2.0
# 24     441949.434244  4.471902e+06     favorable  ...      1.0
# 26     441419.606821  4.473250e+06     favorable  ...      1.0
# 29     441140.297521  4.473142e+06     favorable  ...      3.0
# 41     450605.427171  4.479841e+06     favorable  ...      1.0
# ...              ...           ...           ...  ...      ...
# 10457  439330.129000  4.473728e+06           NaN  ...      NaN
# 10458  442146.054000  4.476054e+06     favorable  ...      NaN
# 10459  450240.390000  4.472880e+06  desfavorable  ...      NaN
# 10460  443468.671000  4.472932e+06  desfavorable  ...      NaN
# 10461  443182.311000  4.473973e+06           NaN  ...      NaN
#
#                                              direccion_1  \
# 20                                      calle de segovia
# 24                                avenida del planetario
# 26     avenida de la ciudad de barcelona             ...
# 29     paseo de santa maria de la cabeza             ...
# 41     glorieta de la ermita de la virgen de la soled...
# ...                                                  ...
# 10457                               plaza. gabriel miro
# 10458                             calle nuñez de balboa
# 10459                                        calle vigil
# 10460                                   autov. m-30 09nc
# 10461                              calle doctor esquerdo
#
#                                              direccion_2  punto_negro  \
# 20     paseo de la virgen del puerto                 ...           45
# 24     calle de mendez alvaro                        ...           34
# 26                                                  None           32
# 29                                                  None           30
# 41                                                  None           41
# ...                                                  ...          ...
# 10457                                               None            1
# 10458                                               None            1
# 10459                                        calle boyer            1
# 10460                                               None            1
# 10461                                       calle moneda            1
#
#       coordenada_x_nueva coordenada_y_nueva coordenada_x_nueva  \
# 20                   NaN                NaN                NaN
# 24                   NaN                NaN                NaN
# 26                   NaN                NaN                NaN
# 29                   NaN                NaN                NaN
# 41                   NaN                NaN                NaN
# ...                  ...                ...                ...
# 10457         439330.129        4473727.919         439330.129
# 10458         442146.054        4476054.421         442146.054
# 10459         450240.390        4472879.964         450240.390
# 10460         443468.671        4472932.015         443468.671
# 10461         443182.311        4473973.169         443182.311
#
#       coordenada_y_nueva    latitud  longitud
# 20                   NaN  40.411827 -3.719797
# 24                   NaN  40.395695 -3.684032
# 26                   NaN  40.407803 -3.690399
# 29                   NaN  40.406811 -3.693680
# 41                   NaN  40.467781 -3.582658
# ...                  ...        ...       ...
# 10457        4473727.919  40.411961 -3.715068
# 10458        4476054.421  40.433120 -3.682093
# 10459        4472879.964  40.405046 -3.586418
# 10460        4472932.015  40.405082 -3.666223
# 10461        4473973.169  40.414442 -3.669690
#
# [5021 rows x 28 columns]

# %% [markdown]
# **Creamos una carpeta para los mapas, dentro de nuestro entorno de trabajo**

# %%
carpeta_mapas = 'mapas'
if not os.path.exists(carpeta_mapas):
    os.makedirs(carpeta_mapas)

# %% [markdown]
# **Vamos a buscar primero los distritos de Madrid para entender mejor los mapas**

# %%
valores_unicos_distrito = df_resultado_final['distrito'].unique()
print(valores_unicos_distrito)
# Out:
# ['arganzuela' 'barajas' 'carabanchel' 'centro' 'chamartin' 'chamberi'
#  'ciudad lineal' 'fuencarral-el pardo' 'hortaleza' 'latina'
#  'moncloa-aravaca' 'moratalaz' 'puente de vallecas' 'retiro' 'salamanca'
#  'san blas-canillejas' 'tetuan' 'usera' 'vicalvaro' 'villa de vallecas'
#  'villaverde']

# %% [markdown]
# **Ahora con la librería geocoder buscamos cada distrito para obtener sus coordenadas**

# %%
# Lista de distritos
distritos = ['centro', 'carabanchel', 'latina', 'usera', 'moncloa-aravaca', 'moratalaz',
 'salamanca', 'villa de vallecas', 'villaverde', 'chamberi', 'chamartin',
 'hortaleza', 'ciudad lineal', 'retiro', 'fuencarral-el pardo', 'vicalvaro',
 'puente de vallecas', 'barajas', 'arganzuela', 'tetuan', 'san blas-canillejas']

# Diccionario para almacenar las coordenadas de los distritos
coordenadas_distritos = {}

# Bucle en geocoder para obtener las coordenadas
for distrito in distritos:
    g = geocoder.osm(f'{distrito}, Madrid')
    
    if g.ok:
        coordenadas_distritos[distrito] = g.latlng

#Imprimimos coordenadas
for distrito, coordenadas in coordenadas_distritos.items():
    print(f'Distrito: {distrito}, Coordenadas: {coordenadas}')
# Out:
# Distrito: centro, Coordenadas: [40.417652700000005, -3.70795469569446]
# Distrito: carabanchel, Coordenadas: [40.3742112, -3.744676]
# Distrito: latina, Coordenadas: [40.4035317, -3.736152]
# Distrito: usera, Coordenadas: [40.383894, -3.7064459]
# Distrito: moncloa-aravaca, Coordenadas: [40.43949485, -3.744206996100531]
# Distrito: moratalaz, Coordenadas: [40.4059332, -3.6448737]
# Distrito: salamanca, Coordenadas: [40.4270451, -3.6806024]
# Distrito: villa de vallecas, Coordenadas: [40.3739576, -3.6121632]
# Distrito: villaverde, Coordenadas: [40.3511231, -3.6997748]
# Distrito: chamberi, Coordenadas: [40.4389621, -3.705302]
# Distrito: chamartin, Coordenadas: [40.4589872, -3.6761288]
# Distrito: hortaleza, Coordenadas: [40.4725491, -3.6425515]
# Distrito: ciudad lineal, Coordenadas: [40.4484305, -3.650495]
# Distrito: retiro, Coordenadas: [40.4111495, -3.6760566]
# Distrito: fuencarral-el pardo, Coordenadas: [40.55634555, -3.7785905137518054]
# Distrito: vicalvaro, Coordenadas: [40.4018377, -3.5950537]
# Distrito: puente de vallecas, Coordenadas: [40.3868601, -3.6591803]
# Distrito: barajas, Coordenadas: [40.4733176, -3.5798446]
# Distrito: arganzuela, Coordenadas: [40.3969535, -3.6972891]
# Distrito: tetuan, Coordenadas: [40.4605781, -3.6982806]
# Distrito: san blas-canillejas, Coordenadas: [40.428919050000005, -3.604002428077398]

# %% [markdown]
# **Vamos a crear un mapa de los distritos de Madrid**

# %%
# Creamos un mapa de Madrid con un punto central y un nivel de zoom inicial
mapa_distritos_madrid = folium.Map(location=[40.416775, -3.703790], zoom_start=12)

# Añadir marcadores para cada distrito utilizando las coordenadas obtenidas previamente
# Es cierto que aquí nos marca un punto "central" en el distrito, no nos marca limitaciones de distritos
for distrito, coordenadas in coordenadas_distritos.items():
    # Añadimos un marcador para cada distrito
    folium.Marker(
        location=coordenadas,  # Aquí usa las coordenadas almacenadas en el diccionario anterior
        popup=distrito,  # Con esto el nombre del distrito aparecerá al hacer clic en el marcador
        icon=folium.Icon(color='red', icon='info-sign')  # Le ponemos color y datos al iconito
    ).add_to(mapa_distritos_madrid)

# Guardamos el mapa en un archivo HTML para visualizarlo en cualquier navegador (es interactivo, no una imagen)
nombre_archivo = "mapa_distritos_madrid.html"
mapa_distritos_madrid.save(nombre_archivo)

print(f"Mapa guardado como {nombre_archivo}")

# Con esto podemos ver el mapa aquí (ojo si contiene muchos datos no cargará... por ejemplo si hacemos todos los accidentes peta)
mapa_distritos_madrid
# Out:
# Mapa guardado como mapa_distritos_madrid.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_84683e9575f15fcf960e3d0ebe865bc7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_84683e9575f15fcf960e3d0ebe865bc7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_84683e9575f15fcf960e3d0ebe865bc7 = L.map(
#                 &quot;map_84683e9575f15fcf960e3d0ebe865bc7&quot;,
#                 {
#                     center: [40.416775, -3.70379],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8671031f9a9107861562312c2012716e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8671031f9a9107861562312c2012716e.addTo(map_84683e9575f15fcf960e3d0ebe865bc7);
#
#
#             var marker_878647ec0795aeca9d9c7faad06ec17d = L.marker(
#                 [40.417652700000005, -3.70795469569446],
#                 {}
#             ).addTo(map_84683e9575f15fcf960e3d0ebe865bc7);
#
#
#             var icon_650396c0ec98e0ff7d990640b6f79906 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_878647ec0795aeca9d9c7faad06ec17d.setIcon(icon_650396c0ec98e0ff7d990640b6f79906);
#
#
#         var popup_2a96fa76a10d2ea2814cc3abfd9e2fb9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c363f9e753da31543143ae50cd2b617d = $(`&lt;div id=&quot;html_c363f9e753da31543143ae50cd2b617d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;centro&lt;/div&gt;`)[0];
#                 popup_2a96fa76a10d2ea2814cc3abfd9e2fb9.setContent(html_c363f9e753da31543143ae50cd2b617d);
#
#
#
#         marker_878647ec0795aeca9d9c7faad06ec17d.bindPopup(popup_2a96fa76a10d2ea2814cc3abfd9e2fb9)
#         ;
#
#
#
#
#             var marker_b74a9dc0076dc255d729b581734b087d = L.marker(
#                 [40.3742112, -3.744676],
#                 {}
#             ).addTo(map_84683e9575f15fcf960e3d0ebe865bc7);
#
#
#             var icon_1c3c6d95c1c6c6d30ac3ce970a4cc514 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b74a9dc0076dc255d729b581734b087d.setIcon(icon_1c3c6d95c1c6c6d30ac3ce970a4cc514);
#
#
#         var popup_bba0804c4b21cc0c4a4647f283fc32b3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d7fd49f3708643e51c71e704a805a0cf = $(`&lt;div id=&quot;html_d7fd49f3708643e51c71e704a805a0cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;carabanchel&lt;/div&gt;`)[0];
#                 popup_bba0804c4b21cc0c4a4647f283fc32b3.setContent(html_d7fd49f3708643e51c71e704a805a0cf);
#
#
#
#         marker_b74a9dc0076dc255d729b581734b087d.bindPopup(popup_bba0804c4b21cc0c4a4647f283fc32b3)
#         ;
#
#
#
#
#             var marker_7df8937c61d162c870d7a1d77e9e4016 = L.marker(
#                 [40.4035317, -3.736152],
#                 {}
#             ).addTo(map_84683e9575f15fcf960e3d0ebe865bc7);
#
#
#             var icon_4f4c4953c4982b78284b9f1feadaae5b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7df8937c61d162c870d7a1d77e9e4016.setIcon(icon_4f4c4953c4982b78284b9f1feadaae5b);
#
#
#         var popup_30c4ded79b0b1fe57dd564132430b4ff = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1cbf212fa42e9bc61deb5d10149f4d68 = $(`&lt;div id=&quot;html_1cbf212fa42e9bc61deb5d10149f4d68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;latina&lt;/div&gt;`)[0];
#                 popup_30c4ded79b0b1fe57dd564132430b4ff.setContent(html_1cbf212fa42e9bc61deb5d10149f4d68);
#
#
#
#         marker_7df8937c61d162c870d7a1d77e9e4016.bindPopup(popup_30c4ded79b0b1fe57dd564132430b4ff)
#         ;
#
#
#
#
#             var marker_507b20527b33f111d934228805be7112 = L.marker(
#                 [40.383894, -3.7064459],
#                 {}
#             ).addTo(map_84683e9575f15fcf960e3d0ebe865bc7);
#
#
#             var icon_946eacd8fc47061e389a07ac0c5aed2f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;marke

# %% [markdown]
# **Aquí vamos a utilizar CHOROPLETH y con un json descargado de la página del ayuntamiento de Madrid para graficar distritos**

# %%
# Cargamos el archivo shp que tenemos en la carpeta mapas
gdf = gpd.read_file('mapas/Distritos.shp')
gdf = gdf.to_crs(epsg=4326)  # Convertir a WGS84, necesario para cargar datos aquí

# Distritos de Madrid. Lo suyo sería encontrar los datos en un geojson... pero bueno, para otro día, los metemos a mano
distritos = ['centro', 'arganzuela', 'retiro', 'salamanca', 'chamartin', 'tetuan', 'chamberi', 'fuencarral-el pardo', 
 'moncloa-aravaca', 'latina', 'carabanchel', 'usera', 'puente-vallecas', 'moratalaz', 'ciudad lineal', 'hortaleza', 'villaverde',  
 'villa de vallecas', 'vicalvaro', 'san blas-canillejas','barajas']

# Añadimos los nombres de los distritos
gdf['nombre_distrito'] = distritos

# Creamos el mapa de Folium centrado en Madrid
m = folium.Map(location=[40.416775, -3.703790], zoom_start=11)

# Añadimos las líneas de los distritos al mapa y añadimos un marcador con el nombre del distrito
for _, row in gdf.iterrows():
    folium.GeoJson(row['geometry'], name=row['nombre_distrito']).add_to(m)
    folium.Marker(
        location=[row['geometry'].centroid.y, row['geometry'].centroid.x],
        popup=row['nombre_distrito'],
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(m)

# Guardarmos
nombre_archivo = "mapas/mapa_distritos_madrid_folium.html"
m.save(nombre_archivo)

# Mostrar el mapa
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9b39b95f8f85de347431422e177b63a1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9b39b95f8f85de347431422e177b63a1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9b39b95f8f85de347431422e177b63a1 = L.map(
#                 &quot;map_9b39b95f8f85de347431422e177b63a1&quot;,
#                 {
#                     center: [40.416775, -3.70379],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7dbd3d767f71a1328229fd978ffa144a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7dbd3d767f71a1328229fd978ffa144a.addTo(map_9b39b95f8f85de347431422e177b63a1);
#
#
#
#         function geo_json_787dfb0f2d3b50d452078d86c93cfd2e_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_787dfb0f2d3b50d452078d86c93cfd2e = L.geoJson(null, {
#                 onEachFeature: geo_json_787dfb0f2d3b50d452078d86c93cfd2e_onEachFeature,
#
#         });
#
#         function geo_json_787dfb0f2d3b50d452078d86c93cfd2e_add (data) {
#             geo_json_787dfb0f2d3b50d452078d86c93cfd2e
#                 .addData(data);
#         }
#             geo_json_787dfb0f2d3b50d452078d86c93cfd2e_add({&quot;coordinates&quot;: [[[-3.693161585718333, 40.40734528727888], [-3.693201773536808, 40.4071959463952], [-3.6932274308515494, 40.406985700371926], [-3.693677073806337, 40.407127242282435], [-3.6938492817793307, 40.407256030453624], [-3.6939030851289854, 40.40728516809562], [-3.693965754713818, 40.40729389112085], [-3.694104837242087, 40.407272606599214], [-3.6952889052391145, 40.406952344625594], [-3.6954111066518958, 40.40699701627571], [-3.697874925626585, 40.406347226392576], [-3.6979426046932513, 40.40632753938889], [-3.6993773095187152, 40.40592797597742], [-3.7000812170601214, 40.40573353840641], [-3.7009844802975294, 40.40550104194435], [-3.701001504462344, 40.4054963423089], [-3.702552444526875, 40.405068199458654], [-3.7029722841757087, 40.40506294765471], [-3.7038858323876367, 40.40519748612806], [-3.7065073323477185, 40.40567809387857], [-3.707097247320552, 40.40579963527812], [-3.708402911664316, 40.40606867160408], [-3.709537756547479, 40.40627703760277], [-3.70991378339443, 40.40632986757442], [-3.7112831748061157, 40.40656182215155], [-3.711677992972163, 40.40666426076095], [-3.712048179493894, 40.40674405590033], [-3.713693111136358, 40.407443568993784], [-3.715231600747346, 40.40808236446719], [-3.7167704590433206, 40.40869762432023], [-3.7183380206462275, 40.41111269571715], [-3.7178516113221947, 40.412077522475165], [-3.7169394290437143, 40.413916071527055], [-3.719431977535446, 40.413934838195594], [-3.7196378174210114, 40.41393959503381], [-3.720495414802149, 40.4139524575968], [-3.722953860062372, 40.41398929063193], [-3.7228501189621017, 40.41533165825695], [-3.7223791480532715, 40.41717496981869], [-3.7221607454238415, 40.41803606736077], [-3.722053178397043, 40.418459803456734], [-3.7218427695123806, 40.41858039604785], [-3.7215099300149967, 40.41877094084414], [-3.7210666691974628, 40.4191186603222], [-3.7206994651329874, 40.41946941752738], [-3.7204000059899585, 40.41989488768215], [-3.7202984802891677, 40.42006840268112], [-3.7201952158463767, 40.420244722118994], [-3.7201893121862626, 40.4202548490104], [-3.7180604801609145, 40.42028704097163], [-3.7168022792795625, 40.42034218118273], [-3.7159793942392727, 40.42035340085404], [-3.7155047630699163, 40.42040273211803], [-3.715504057769815, 40.42040291666361], [-3.713896283217111, 40.42147780435128], [-3.7133817275171905, 40.421821789496626], [-3.713331795947794, 40.42190453022456], [-3.713174757453032, 40.422058381409315], [-3.713042917613715, 40.42218748321381], [-3.7117220188510807, 40.42296372420551], [-3.7111628385687476, 40.423292298433175], [-3.710917008734835, 40.42342209712828], [-3.710894267631762, 40.423434128884416], [-3.7117077280551243, 40.42430381791785], [-3.7124572841128374, 40.42536038173157], [-3.7131738711965423, 40.42640714380478], [-3.713896944113725, 40.427463231430394], [-3.7141324539932015, 40.42778376116431], [-3.714527522241789, 40.42832105509785], [-3.715595782756464, 40.429774009826964], [-3.7161957949201834, 40.430602644653334], [-3.716228339682088, 40.430647668298015], [-3.714629542752751, 40.430476670290965], [-3.713523082844121, 40.43036077113891], [-3.7118615190482105, 40.430194245610174], [-3.7105035893637304, 40.430055200800005], [-3.708826198049883, 40.42988486399868], [-3.7077157683688013, 40.42978282094671], [-3.70741332493008, 40.42975501521785], [-3.7058059637923653, 40.42960556189141], [-3.703644873577472, 40.42924087994932], [-3.7024063074800546, 40.42905885291728], [-3.701946605023671, 40.428974793534444], [-3.699410644853255, 40.428425909257484], [-3.69713054167271, 40.4279449844499], [-3.695761797894772,

# %% [markdown]
# ** Vamos a graficar ahora únicamente los datos del 2024 que solo tenemos un mes para que se vea la cantidad de
# accidentes que hay en Madrid y lo "feo" que ser vería con todos los puntos. Más que nada es para trasladar la cantidad
# de puntos que podría tener si nos diera por graficar todos los accidentes desde el año 2010... ni se podría abrir**

# %%
df_2024 = df_coordenadas[pd.to_datetime(df_coordenadas['fecha']).dt.year == 2024]

df_2024 = df_2024.dropna(subset=['latitud', 'longitud'])

# Creamos un mapa centrado en una ubicación aproximada de Madrid
accidentes_madrid_2024 = folium.Map(location=[40.416775, -3.703790], zoom_start=12)

# Añadimos marcadores para cada accidente
for _, accidente in df_2024.iterrows():
    folium.Marker(
        location=[accidente['latitud'], accidente['longitud']],
        popup=f"Accidente ID: {accidente['accidente_id']}"
    ).add_to(accidentes_madrid_2024)

# Guardamos
nombre_archivo = "mapas/accidentes_madrid_2024.html"
accidentes_madrid_2024.save(nombre_archivo)

print(f"Mapa guardado como {nombre_archivo}")
accidentes_madrid_2024
# Out:
# Mapa guardado como mapas/accidentes_madrid_2024.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_77b4388eda7e99b15ecef9dce0b34896 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_77b4388eda7e99b15ecef9dce0b34896&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_77b4388eda7e99b15ecef9dce0b34896 = L.map(
#                 &quot;map_77b4388eda7e99b15ecef9dce0b34896&quot;,
#                 {
#                     center: [40.416775, -3.70379],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0abb58c595c9476b15231d2f81322447 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0abb58c595c9476b15231d2f81322447.addTo(map_77b4388eda7e99b15ecef9dce0b34896);
#
#
#             var marker_d9496c65e62f0e286f8a2bfc70916dee = L.marker(
#                 [40.44706271079276, -3.654040551404652],
#                 {}
#             ).addTo(map_77b4388eda7e99b15ecef9dce0b34896);
#
#
#         var popup_3625b5c9230f5d3183334bbeddcad5a1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6bf48bca08756175e60910e81f78e5a4 = $(`&lt;div id=&quot;html_6bf48bca08756175e60910e81f78e5a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Accidente ID: 2024.001988&lt;/div&gt;`)[0];
#                 popup_3625b5c9230f5d3183334bbeddcad5a1.setContent(html_6bf48bca08756175e60910e81f78e5a4);
#
#
#
#         marker_d9496c65e62f0e286f8a2bfc70916dee.bindPopup(popup_3625b5c9230f5d3183334bbeddcad5a1)
#         ;
#
#
#
#
#             var marker_eb85474f1190997ba6c683c84ebd68fe = L.marker(
#                 [40.44706271079276, -3.654040551404652],
#                 {}
#             ).addTo(map_77b4388eda7e99b15ecef9dce0b34896);
#
#
#         var popup_a0258ffafa02588ca28308a40a91d7cc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bef37eb12d0b548e015c32c7a4da7ce7 = $(`&lt;div id=&quot;html_bef37eb12d0b548e015c32c7a4da7ce7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Accidente ID: 2024.000544&lt;/div&gt;`)[0];
#                 popup_a0258ffafa02588ca28308a40a91d7cc.setContent(html_bef37eb12d0b548e015c32c7a4da7ce7);
#
#
#
#         marker_eb85474f1190997ba6c683c84ebd68fe.bindPopup(popup_a0258ffafa02588ca28308a40a91d7cc)
#         ;
#
#
#
#
#             var marker_70788d4e7e8c49bb1b5f249912d0c2ca = L.marker(
#                 [40.44706271079276, -3.654040551404652],
#                 {}
#             ).addTo(map_77b4388eda7e99b15ecef9dce0b34896);
#
#
#         var popup_ad3bbd6e9ae9adc23d54c783eebfbd79 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_af2441d5ebe047528b0ab96e0ed41010 = $(`&lt;div id=&quot;html_af2441d5ebe047528b0ab96e0ed41010&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Accidente ID: 2024.00116&lt;/div&gt;`)[0];
#                 popup_ad3bbd6e9ae9adc23d54c783eebfbd79.setContent(html_af2441d5ebe047528b0ab96e0ed41010);
#
#
#
#         marker_70788d4e7e8c49bb1b5f249912d0c2ca.bindPopup(popup_ad3bbd6e9ae9adc23d54c783eebfbd79)
#         ;
#
#
#
#
#             var marker_0dc15f53208005375725d68552921f8a = L.marker(
#                 [40.37805799004686, -3.719087963856512],
#                 {}
#             ).addTo(map_77b4388eda7e99b15ecef9dce0b34896);
#
#
#         var popup_c6c0c724f3b358ed62c79f9639097e36 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f861b84a00b38ce7707c8d24e50a2265 = $(`&lt;div id=&quot;html_f861b84a00b38ce7707c8d24e50a2265&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Accidente ID: 2024.001652&lt;/div&gt;`)[0];
#                 popup_c6c0c724f3b358ed62c79f9639097e36.setContent(html_f861b84a00b38ce7707c8d24e50a2265);
#
#
#
#         marker_0dc15f53208005375725d68552921f8a.bindPopup(popup_c6c0c724f3b358ed62c79f9639097e36)
#         ;
#
#
#
#
#             var marker_18ecb2cd37d8328ac4f554c6291c4549 = L.marker(
#                 [40.37805799004686, -3.719087963856512],
#                 {}
#             ).addTo(map_77b4388eda7e99b15ecef9dce0b34896);
#
#
#         var popup_993b12b33cb0ab3b50bc4c4dec8d8d22 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ef22408515ca7a8637eff79762dd47bd = $(`&lt;div id=&quot;html_ef22408515ca7a8637eff79762dd47bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Accidente ID: 2024.001585&lt;/div&gt;`)[0];
#                 popup_993b12b33cb0ab3b50bc4c4dec8d8d22.setContent(html_ef22408515ca7a8637eff79762dd47bd);
#
#
#
#         marker_18ecb2cd37d8328ac4f554c6291c4549.bindPopup(popup_993b12b33cb0ab3b50bc4c4dec8d8d22)
#         ;
#
#
#
#
#             var marker_41abf9065623a1dbaac39562a3

# %% [markdown]
# **Ahora vamos a crear un mapa con el top 20 de puntos negros en Madrid por barrios desde el 2010 a la actudalidad**
#
# También se podría hacer por años, meses... pero bueno, como es para bonito nos sobra...
#
# Hay que hacer un merge para tener coordenadas y el ranking que están en dos df separados

# %%
# Realizar el merge entre df_agrupado y df_coordenadas usando 'localizacion_completa'
df_merged = df_agrupado.merge(df_coordenadas, on='localizacion_completa', how='left')

# Asegurarte de que df_merged está ordenado por 'ranking_punto_negro'
df_merged_sorted = df_merged.sort_values(by='ranking_punto_negro')

# Asegurarse de que no hay NaNs en las columnas 'latitud' y 'longitud'
top_puntos_por_distrito = top_puntos_por_distrito.dropna(subset=['latitud', 'longitud'])

# Crear un mapa de Folium centrado en Madrid
mapa_top_accidentes_madrid = folium.Map(location=[40.416775, -3.703790], zoom_start=11)

# Iterar
for _, punto in top_puntos_por_distrito.iterrows():
    folium.Marker(
        location=[punto['latitud'], punto['longitud']],
        popup=(
            f"Distrito: {punto['distrito_x']}<br>"
            f"Localización: {punto['localizacion_completa']}<br>"
            f"Ranking Punto Negro: {punto['ranking_punto_negro']}"
        ),
        icon=folium.Icon(color='red', icon='info-sign')
    ).add_to(mapa_top_accidentes_madrid)

# Guardar
mapa_top_accidentes_madrid.save('mapas/mapa_top_accidentes_madrid.html')
mapa_top_accidentes_madrid
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1ebdc1367f4e605f161ea3556903a6c5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1ebdc1367f4e605f161ea3556903a6c5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1ebdc1367f4e605f161ea3556903a6c5 = L.map(
#                 &quot;map_1ebdc1367f4e605f161ea3556903a6c5&quot;,
#                 {
#                     center: [40.416775, -3.70379],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_039e3f86cd2131e8448478d950cf6a47 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_039e3f86cd2131e8448478d950cf6a47.addTo(map_1ebdc1367f4e605f161ea3556903a6c5);
#
#
#             var marker_b998f3ca3e4ad9d43342acda15b93765 = L.marker(
#                 [40.45900540103424, -3.6897095500120316],
#                 {}
#             ).addTo(map_1ebdc1367f4e605f161ea3556903a6c5);
#
#
#             var icon_7e98140f802e1acd6afe824af5258e5f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b998f3ca3e4ad9d43342acda15b93765.setIcon(icon_7e98140f802e1acd6afe824af5258e5f);
#
#
#         var popup_0adfc40b637b93a68a9de69012d50801 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8f4e8f76b0a3c3e41d74ef80223c8f28 = $(`&lt;div id=&quot;html_8f4e8f76b0a3c3e41d74ef80223c8f28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Distrito: chamartin&lt;br&gt;Localización: paseo de la castellana - plaza de lima                                                              &lt;br&gt;Ranking Punto Negro: 1&lt;/div&gt;`)[0];
#                 popup_0adfc40b637b93a68a9de69012d50801.setContent(html_8f4e8f76b0a3c3e41d74ef80223c8f28);
#
#
#
#         marker_b998f3ca3e4ad9d43342acda15b93765.bindPopup(popup_0adfc40b637b93a68a9de69012d50801)
#         ;
#
#
#
#
#             var marker_35c3f065c6f6cadb60b0d17aa6ae6910 = L.marker(
#                 [40.39366125966081, -3.674881004752408],
#                 {}
#             ).addTo(map_1ebdc1367f4e605f161ea3556903a6c5);
#
#
#             var icon_8ebffc81d6f895671c47b75d167ea03b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_35c3f065c6f6cadb60b0d17aa6ae6910.setIcon(icon_8ebffc81d6f895671c47b75d167ea03b);
#
#
#         var popup_423ee60efde9531a4662414abeda1619 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_29eb63b773d41206e716fda98f2e31e5 = $(`&lt;div id=&quot;html_29eb63b773d41206e716fda98f2e31e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Distrito: arganzuela&lt;br&gt;Localización: autov. m-30 +01100i, +11i&lt;br&gt;Ranking Punto Negro: 2&lt;/div&gt;`)[0];
#                 popup_423ee60efde9531a4662414abeda1619.setContent(html_29eb63b773d41206e716fda98f2e31e5);
#
#
#
#         marker_35c3f065c6f6cadb60b0d17aa6ae6910.bindPopup(popup_423ee60efde9531a4662414abeda1619)
#         ;
#
#
#
#
#             var marker_4dae463776cd45fa8d640c7c722419c1 = L.marker(
#                 [40.39366125966081, -3.674881004752408],
#                 {}
#             ).addTo(map_1ebdc1367f4e605f161ea3556903a6c5);
#
#
#             var icon_6fb042c54bdd59c834d97d59a19c1ca2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4dae463776cd45fa8d640c7c722419c1.setIcon(icon_6fb042c54bdd59c834d97d59a19c1ca2);
#
#
#         var popup_63e14a4e041aaff5fbf50eb1650dd4f2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_512830adbb79e78cf8e793d274f2ea1c = $(`&lt;div id=&quot;html_512830adbb79e78cf8e793d274f2ea1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Distrito: arganzuela&lt;br&gt;Localización: autov. m-30 +01100i, +11i&lt;br&gt;Ranking Punto Negro: 2&lt;/div&gt;`)[0];
#                 popup_63e14a4e041aaff5fbf50eb1650dd4f2.setContent(html_512830adbb79e78cf8e793d274f2ea1c);
#
#
#
#         marker_4dae463776cd45fa8d640c7c722419c1.bindPopup(popup_63e14a4e041aaff5fbf50eb1650dd4f2)
#         ;
#
#
#
#
#             var marker_2224f0de64511cbbd854eb6df7eca46e
